# %% [markdown]
# <a href="https://colab.research.google.com/github/HamzaWajid1/Zabaan_v1/blob/main/Copy_of_Copy_of_Imagine_Cup_project(7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-6-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     131     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
pip install ibm_watson
# Out:
# Collecting ibm_watson
#   Downloading ibm-watson-7.0.1.tar.gz (389 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.3/389.3 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: websocket-client>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (1.7.0)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6 (from ibm_watson)
#   Downloading ibm-cloud-sdk-core-3.19.1.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 7.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3<3.0.0,>=2.1.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 14.3 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2023.11.17)
# Building wheels for collected packages: ibm_watson, ibm-cloud-sdk-core
#   Building wheel for ibm_watson (pyproject.toml) ... done
#   Created wheel for ibm_watson: filename=ibm_watson-7.0.1-py3-none-any.whl size=389784 sha256=9648657af5de36c87135e034214a91ada2e8c7731f34d851e8b16f7733084e5a
#   Stored in directory: /root/.cache/pip/wheels/34/df/f4/f8edc5ba0637dd4bfb2029741ae20402976a49d1b6bc113553
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml) ... done
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.19.1-py3-none-any.whl size=95828 sha256=d73de31453c1442dd6c0a38e47557c37f4549b557eccb03499025e5b7e0ada3b
#   Stored in directory: /root/.cache/pip/wheels/d9/b9/b2/2316e6df1fb93353a388ef07032b10655ca871c173b241e788
# Successfully built ibm_watson ibm-cloud-sdk-core
# Installing collected packages: urllib3, PyJWT, ibm-cloud-sdk-core, ibm_watson
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# Successfully installed PyJWT-2.8.0 ibm-cloud-sdk-core-3.19.1 ibm_watson-7.0.1 urllib3-2.1.0

# %%
pip install timestamps
# Out:
# Collecting timestamps
#   Downloading timestamps-1.3.0-py3-none-any.whl (3.1 kB)
# Installing collected packages: timestamps
# Successfully installed timestamps-1.3.0

# %%
# %pip install requests uuid
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Collecting uuid
#   Downloading uuid-1.30.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Building wheels for collected packages: uuid
#   Building wheel for uuid (setup.py) ... done
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6479 sha256=148e860643ffa10213cfe9d93891d488cb5b9dfb12f3042e818ba2d303e0a5cf
#   Stored in directory: /root/.cache/pip/wheels/ed/08/9e/f0a977dfe55051a07e21af89200125d65f1efa60cbac61ed88
# Successfully built uuid
# Installing collected packages: uuid
# Successfully installed uuid-1.30

# %%
#@title Automatic Setup
# %pwd
# !git clone https://github.com/jaywalnut310/vits.git
# !python --version
# %cd vits/

# !pip install Cython==0.29.21
# !pip install librosa==0.8.0
# !pip install phonemizer==2.2.1
# !pip install scipy
# !pip install numpy
# !pip install torch
# !pip install torchvision
# !pip install matplotlib
# !pip install Unidecode==1.1.1

# %cd monotonic_align/
# %mkdir monotonic_align
# !python3 setup.py build_ext --inplace
# %cd ../
# %pwd
# Out:
# Cloning into 'vits'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 81 (delta 21), reused 21 (delta 21), pack-reused 26
# Receiving objects: 100% (81/81), 3.33 MiB | 7.04 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Python 3.10.12
# /content/vits
# Collecting Cython==0.29.21
#   Downloading Cython-0.29.21-py2.py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.2/974.2 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: Cython
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed Cython-0.29.21
# Collecting librosa==0.8.0
#   Downloading librosa-0.8.0.tar.gz (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (3.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (1.23.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (1.11.4)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (1.3.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.8.0)
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (0.58.1)
# Requirement already satisfied: soundfile>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.8.0) (1.8.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.43.0->librosa==0.8.0) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.8.0) (4.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.8.0) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.8.0) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.9.0->librosa==0.8.0) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.8.0) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0) (2023.11.17)
# Building wheels for collected packages: librosa
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201368 sha256=be24ee9c03b8edeec4f94b2e168c5a4ba8a9d4e961514345d80a42d630157640
#   Stored in directory: /root/.cache/pip/wheels/bf/b7/85/2f8044306ccec014930aea23ad4852fca9e2584e21c6972bc6
# Successfully built librosa
# Installing collected packages: resampy, librosa
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# Successfully installed librosa-0.8.0 resampy-0.4.2
# Collecting phonemizer==2.2.1
#   Downloading phonemizer-2.2.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from phonemizer==2.2.1) (1.3.2)
# Collecting segments (from phonemizer==2.2.1)
#   Downloading segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.10/dist-packages (from phonemizer==2.2.1) (23.2.0)
# Collecting clldutils>=1.7.3 (from segments->phonemizer==2.2.1)
#   Downloading clldutils-3.22.1-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.9 MB/s eta 0:00:00
# Collecting csvw>=1.5.6 (from segments->phonemizer==2.2.1)
#   Downloading csvw-3.3.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from segments->phonemizer==2.2.1) (2023.6.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (2.8.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (0.9.0)
# Collecting colorlog (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Collecting bibtexparser>=2.0.0b4 (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Downloading bibtexparser-2.0.0b6-py3-none-any.whl (38 kB)
# Collecting pylatexenc (from clldutils>=1.7.3->segments->phonemizer==2.2.1)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (3.5.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (4.9.4)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer==2.2.1) (2.1.4)
# Requirement already satisfied: babel in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer==2.2.1) (2.14.0)
# Collecting colorama (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer==2.2.1) (4.19.2)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 15.2 MB/s eta 0:00:00
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer==2.2.1) (2.31.0)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer==2.2.1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer==2.2.1) (4.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate->csvw>=1.5.6->segments->phonemizer==2.2.1) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer==2.2.1) (0.17.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer==2.2.1) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer==2.2.1) (2023.11.17)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=40e09bff6c449c6fa864d4004fabd072cb14592afa96f339261007792acb50d5
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# Installing collected packages: rfc3986, pylatexenc, language-tags, isodate, colorlog, colorama, bibtexparser, rdflib, clldutils, csvw, segments, phonemizer
# Successfully installed bibtexparser-2.0.0b6 clldutils-3.22.1 colorama-0.4.6 colorlog-6.8.0 csvw-3.3.0 isodate-0.6.1 language-tags-1.2.0 phonemizer-2.2.1 pylatexenc-2.10 rdflib-7.0.0 rfc3986-1.5.0 segments-2.2.1
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.1.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0->torchvision) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0->torchvision) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting Unidecode==1.1.1
#   Downloading Unidecode-1.1.1-py2.py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.3/238.3 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.1.1
# /content/vits/monotonic_align
# Compiling core.pyx because it changed.
# [1/1] Cythonizing core.pyx
# /usr/local/lib/python3.10/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/vits/monotonic_align/core.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# core.c: In function ‘__Pyx_InitGlobals’:
# core.c:16766:1: warning: ‘PyEval_InitThreads’ is deprecated [-Wdeprecated-declarations]
# 16766 | PyEval_InitThreads();
#       | ^~~~~~~~~~~~~~~~~~
# In file included from /usr/include/python3.10/Python.h:130,
#                  from core.c:16:
# /usr/include/python3.10/ceval.h:122:37: note: declared here
#   122 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#       |                                     ^~~~~~~~~~~~~~~~~~
# /content/vits
# '/content/vits'

# %%
# %pip install fire
# Out:
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire) (2.4.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=80036e7eeeed9d4420dc9e51ad3bc77a9e05090467e09f1aabd50b874726cb3a
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.5.0

# %%
pip install commons
# Out:
# Collecting commons
#   Downloading commons-0.7.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import subprocess
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
from moviepy.editor import VideoFileClip, AudioFileClip, concatenate_videoclips
import os

# %%
import torch
torch.cuda.empty_cache()

# %%
import soundfile as sf
from IPython.display import Audio
import shutil

# %%
#@title Select Language { run: "auto" }
LANG = "pan" #@param {type:"string"}
import os
import subprocess
import locale
locale.getpreferredencoding = lambda: "UTF-8"

def download(lang, tgt_dir="./"):
  lang_fn, lang_dir = os.path.join(tgt_dir, lang+'.tar.gz'), os.path.join(tgt_dir, lang)
  cmd = ";".join([
        f"wget https://dl.fbaipublicfiles.com/mms/tts/{lang}.tar.gz -O {lang_fn}",
        f"tar zxvf {lang_fn}"
  ])
  print(f"Download model for language: {lang}")
  subprocess.check_output(cmd, shell=True)
  print(f"Model checkpoints in {lang_dir}: {os.listdir(lang_dir)}")
  return lang_dir

ckpt_dir = download(LANG)

from IPython.display import Audio
import os
import re
import glob
import json
import tempfile
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
import numpy as np
import commons
import utils
import argparse
import subprocess
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from scipy.io.wavfile import write

def preprocess_char(text, lang=None):
    """
    Special treatement of characters in certain languages
    """
    print(lang)
    if lang == 'ron':
        text = text.replace("ț", "ţ")
    return text

class TextMapper(object):
    def __init__(self, vocab_file):
        self.symbols = [x.replace("\n", "") for x in open(vocab_file, encoding="utf-8").readlines()]
        self.SPACE_ID = self.symbols.index(" ")
        self._symbol_to_id = {s: i for i, s in enumerate(self.symbols)}
        self._id_to_symbol = {i: s for i, s in enumerate(self.symbols)}

    def text_to_sequence(self, text, cleaner_names):
        '''Converts a string of text to a sequence of IDs corresponding to the symbols in the text.
        Args:
        text: string to convert to a sequence
        cleaner_names: names of the cleaner functions to run the text through
        Returns:
        List of integers corresponding to the symbols in the text
        '''
        sequence = []
        clean_text = text.strip()
        for symbol in clean_text:
            symbol_id = self._symbol_to_id[symbol]
            sequence += [symbol_id]
        return sequence

    def uromanize(self, text, uroman_pl):
        iso = "xxx"
        with tempfile.NamedTemporaryFile() as tf, \
             tempfile.NamedTemporaryFile() as tf2:
            with open(tf.name, "w") as f:
                f.write("\n".join([text]))
            cmd = f"perl " + uroman_pl
            cmd += f" -l {iso} "
            cmd +=  f" < {tf.name} > {tf2.name}"
            os.system(cmd)
            outtexts = []
            with open(tf2.name) as f:
                for line in f:
                    line =  re.sub(r"\s+", " ", line).strip()
                    outtexts.append(line)
            outtext = outtexts[0]
        return outtext

    def get_text(self, text, hps):
        text_norm = self.text_to_sequence(text, hps.data.text_cleaners)
        if hps.data.add_blank:
            text_norm = commons.intersperse(text_norm, 0)
        text_norm = torch.LongTensor(text_norm)
        return text_norm

    def filter_oov(self, text):
        val_chars = self._symbol_to_id
        txt_filt = "".join(list(filter(lambda x: x in val_chars, text)))
        return txt_filt

def preprocess_text(txt, text_mapper, hps, uroman_dir=None, lang=None):
    txt = preprocess_char(txt, lang=lang)
    is_uroman = hps.data.training_files.split('.')[-1] == 'uroman'
    if is_uroman:
        with tempfile.TemporaryDirectory() as tmp_dir:
            if uroman_dir is None:
                cmd = f"git clone git@github.com:isi-nlp/uroman.git {tmp_dir}"
                print(cmd)
                subprocess.check_output(cmd, shell=True)
                uroman_dir = tmp_dir
            uroman_pl = os.path.join(uroman_dir, "bin", "uroman.pl")
            print(f"uromanize")
            txt = text_mapper.uromanize(txt, uroman_pl)
            print(f"uroman text: {txt}")
    txt = txt.lower()
    txt = text_mapper.filter_oov(txt)
    return txt

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"Run inference with {device}")
vocab_file = f"{ckpt_dir}/vocab.txt"
config_file = f"{ckpt_dir}/config.json"
assert os.path.isfile(config_file), f"{config_file} doesn't exist"
hps = utils.get_hparams_from_file(config_file)
text_mapper = TextMapper(vocab_file)
net_g = SynthesizerTrn(
    len(text_mapper.symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model)
net_g.to(device)
_ = net_g.eval()

g_pth = f"{ckpt_dir}/G_100000.pth"
print(f"load {g_pth}")

_ = utils.load_checkpoint(g_pth, net_g, None)
# Out:
# Download model for language: pan
# Model checkpoints in ./pan: ['G_100000.pth', 'config.json', 'vocab.txt']
# [WARNING] /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Run inference with cuda
# load ./pan/G_100000.pth

# %%
apikey = 'h3bMgb4Tldj2cqh9PDA2KieD1kprny4CpQBXp_TttbpB'
url = 'https://api.au-syd.speech-to-text.watson.cloud.ibm.com/instances/43b3559e-bba6-427b-b4c2-3a5f6a601855'

# %%
import requests, uuid, json

# Add your key and endpoint
key = "ded01807d1b340f9ac302e611498c392"
endpoint = "https://api.cognitive.microsofttranslator.com"

# location, also known as region.
# required if you're using a multi-service or regional (not global) resource. It can be found in the Azure portal on the Keys and Endpoint page.
location = "southeastasia"

path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': ['pa']
}

headers = {
    'Ocp-Apim-Subscription-Key': key,
     # location required if you're using a multi-service or regional (not global) resource.
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# %%
# importing the module
from pytube import YouTube

# where to save
SAVE_PATH = "E:/" #to_do

# link of the video to be downloaded
link="https://www.youtube.com/watch?v=A98wPKiPMJw"
yt = YouTube(link)

try:
    yt.streams.filter(progressive = True,
file_extension = "mp4").first().download(output_path = "/content/",
filename = "a.mp4")
except:
    print("Some Error!")
print('Task Completed!')
# Out:
# Task Completed!

# %%
command = 'ffmpeg -i /content/a.mp4 -ab 160k -ar 44100 -vn /content/audio.wav'
subprocess.call(command, shell=True)
# Out:
# 0

# %%
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)
#"imagine that all the recessions disappeared for a day and imagine that you being the excellent explore you are decided to go investigate you travel across the continental shelf down the content of folk and across the business plan you'd think gaping trenches running deep into the ground and mountains total any mountain on the contents and you may wonder what causes such dramatic landscapes to be formed

# %%
with open('/content/audio.wav', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/wav', model='en-AU_NarrowbandModel', timestamps=True).get_result()

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': "imagine that all the recessions disappeared for a day and imagine that you being the excellent explore you are decided to go investigate you travel across the continental shelf down the content of folk and across the business plan you'd think gaping trenches running deep into the ground and mountains total any mountain on the contents and you may wonder what causes such dramatic landscapes to be formed ",
#      'confidence': 0.84,
#      'timestamps': [['imagine', 0.12, 0.64],
#       ['that', 0.64, 0.82],
#       ['all', 0.85, 1.13],
#       ['the', 1.13, 1.27],
#       ['recessions', 1.27, 2.29],
#       ['disappeared', 2.32, 3.05],
#       ['for', 3.05, 3.23],
#       ['a', 3.23, 3.31],
#       ['day', 3.31, 3.78],
#       ['and', 3.92, 4.19],
#       ['imagine', 4.19, 4.56],
#       ['that', 4.56, 4.67],
#       ['you', 4.67, 5.13],
#       ['being', 5.21, 5.45],
#       ['the', 5.45, 5.58],
#       ['excellent', 5.58, 6.13],
#       ['explore', 6.13, 6.65],
#       ['you', 6.65, 6.82],
#       ['are', 6.82, 7.21],
#       ['decided', 7.49, 7.99],
#       ['to', 7.99, 8.11],
#       ['go', 8.11, 8.34],
#       ['investigate', 8.34, 9.34],
#       ['you', 9.75, 9.93],
#       ['travel', 9.93, 10.44],
#       ['across', 10.44, 10.98],
#       ['the', 10.98, 11.08],
#       ['continental', 11.08, 11.6],
#       ['shelf', 11.6, 12.08],
#       ['down', 12.39, 12.73],
#       ['the', 12.73, 12.82],
#       ['content', 12.82, 13.26],
#       ['of', 13.26, 13.34],
#       ['folk', 13.34, 13.89],
#       ['and', 14.16, 14.44],
#       ['across', 14.47, 14.94],
#       ['the', 14.94, 15.11],
#       ['business', 15.11, 15.42],
#       ['plan', 15.42, 15.87],
#       ["you'd", 16.22, 16.42],
#       ['think', 16.42, 16.66],
#       ['gaping', 16.66, 17.0],
#       ['trenches', 17.0, 17.46],
#       ['running', 17.46, 17.69],
#       ['deep', 17.69, 17.94],
#       ['into', 17.94, 18.1],
#       ['the', 18.1, 18.2],
#       ['ground', 18.2, 18.72],
#       ['and', 18.96, 19.24],
#       ['mountains', 19.24, 19.83],
#       ['total', 19.86, 20.38],
#       ['any', 20.46, 20.72],
#       ['mountain', 20.72, 21.02],
#       ['on', 21.02, 21.1],
#       ['the', 21.1, 21.17],
#       ['contents', 21.17, 21.87],
#       ['and', 22.22, 22.54],
#       ['you', 22.54, 22.69],
#       ['may', 22.69, 22.9],
#       ['wonder', 22.9, 23.43],
#       ['what', 23.77, 24.06],
#       ['causes', 24.06, 24.65],
#       ['such', 24.65, 24.97],
#       ['dramatic', 24.97, 25.45],
#       ['landscapes', 25.45, 26.05],
#       ['to', 26.05, 26.15],
#       ['be', 26.15, 26.24],
#       ['formed', 26.24, 26.84]]}]},
#   {'final': True,
#    'alternatives': [{'transcript': 'I respect this year which is made by the crest and upper part of the mantle is broken up into large puzzle piece like chunks because tectonic plates these tectonic plates move around slowly over millions of years in the section of mental below the spirit which because the Steelers here ',
#      'confidence': 0.71,
#      'timestamps': [['I', 27.72, 27.8],
#       ['respect', 27.8, 28.3],
#       ['this', 28.3, 28.51],
#       ['year', 28.51, 28.97],
#       ['which', 29.1, 29.44],
#       ['is', 29.44, 29.67],
#       ['made', 29.67, 29.88],
#       ['by', 29.88, 29.95],
#       ['the', 29.95, 30.05],
#       ['crest', 30.05, 30.6],
#       ['and', 30.63, 30.78],
#       ['upper', 30.78, 31.03],
#       ['part', 31.03, 31.24],
#       ['of', 31.24, 31.3],
#       ['the', 31.3, 31.37],
#       ['mantle', 31.37, 31.86],
#       ['is', 31.96, 32.16],
#       ['broken', 32.16, 32.49],
#       ['up', 32.49, 32.68],
#       ['into', 32.71, 32.99],
#       ['large', 32.99, 33.5],
#       ['puzzle', 33.5, 33.89],
#       ['piece', 33.89, 34.18],
#       ['like', 34.18, 34.39],
#       ['chunks', 34.39, 34.8],
#       ['because', 34.8, 35.15],
#       ['tectonic', 35.15, 35.68],
#       ['plates', 35.68, 36.13],
#       ['these', 36.54, 36.84],
#       ['tectonic', 36.84, 37.27],
#       ['plates', 37.27, 37.72],
#       ['move', 37.75, 38.01],
#       ['around', 38.01, 38.3],
#       ['slowly', 38.3, 38.84],
#       ['over', 38.87, 39.09],
#       ['millions', 39.09, 39.57],
#       ['of', 39.57, 39.66],
#       ['years', 39.66, 40.23],
#       ['in', 40.46, 40.56],
#       ['the', 40.56, 40.65],
#       ['section', 40.65, 41.08],
#       ['of', 41.08, 41.16],
#       ['mental', 41.16, 41.52],
#       ['below', 41.52, 41.74],
#       ['the', 41.74, 42.07],
#       ['spirit', 42.07, 42.52],
#       ['which', 42.73, 43.0],
#       ['because', 43.0, 43.5],
#       ['the', 43.5, 43.68],
#       ['Steelers', 43.68, 44.1],
#       ['here', 44.1, 44.51]]}]},
#   {'final': True,
#    'alternatives': [{'transcript': "there are two types of tectonic plates it was the ethic pleats and continental plates the continental plates as you probably guessed are the ones that make up the confidence that was Yannick pleats are the ones that make up the fee for the main difference between oceanic plates and continental plates is a paper priced finally complete %HESITATION Sienna crest and continental crust only at a different kinds of rock the continental crust contains a lot of granite which is an igneous rock this means that it was made at a rock that was once Malton the oceanic crust has a lot of the soffit which is another kind of igneous rock the difference in the claims of rock but the crusts are made out it means that the oceanic crust is denser than the continental pressed if you took a cubic centimetre of a rock from the customer crashed it would be about two point seven grams a cubic centimetre from the oceanic crust and other hand would weigh about three grams well this difference in density may not seem like much completely changes how tectonic plates interact the high density of authentic craft cause of scenic plates to think it's the same spirit a bit more than continental plate still we're also unique please collides with another place and a convergent boundary it always follows this rule the denser plates always dies beneath the western street with its oceanic plates and a continental plates converging the denser oceanic plates is the one that gets down and when it's two of scenic places are colliding the older denser of scenic please will move under the newer and less dense oceanic plates ",
#      'confidence': 0.75,
#      'timestamps': [['there', 45.63, 45.79],
#       ['are', 45.79, 45.9],
#       ['two', 45.9, 46.21],
#       ['types', 46.21, 46.56],
#       ['of', 46.56, 46.69],
#       ['tectonic', 46.69, 47.11],
#       ['plates', 47.11, 47.54],
#       ['it', 47.86, 47.92],
#       ['was', 47.92, 48.04],
#       ['the', 48.04, 48.15],
#       ['ethic', 48.15, 48.38],
#       ['pleats', 48.38, 48.91],
#       ['and', 48.94, 49.15],
#       ['continental', 49.15, 49.65],
#       ['plates', 49.65, 50.08],
#       ['the', 50.58, 50.7],
#       ['continental', 50.7, 51.25],
#       ['plates', 51.25, 51.83],
#       ['as', 51.91, 52.12],
#       ['you', 52.12, 52.23],
#       ['probably', 52.23, 52.66],
#       ['guessed', 52.66, 53.19],
#       ['are', 53.51, 53.67],
#       ['the', 53.67, 53.77],
#       ['ones', 53.77, 54.01],
#       ['that', 54.01, 54.13],
#       ['make', 54.13, 54.28],
#       ['up', 54.28, 54.39],
#       ['the', 54.39, 54.47],
#       ['confidence', 54.47, 55.17],
#       ['that', 55.47, 55.66],
#       ['was', 55.66, 55.82],
#       ['Yannick', 55.82, 56.22],
#       ['pleats', 56.22, 56.77],
#       ['are', 56.8, 56.93],
#       ['the', 56.93, 57.03],
#       ['ones', 57.03, 57.32],
#       ['that', 57.32, 57.44],
#       ['make', 57.44, 57.6],
#       ['up', 57.6, 57.81],
#       ['the', 57.81, 57.93],
#       ['fee', 57.93, 58.18],
#       ['for', 58.18, 58.72],
#       ['the', 59.0, 59.15],
#       ['main', 59.15, 59.46],
#       ['difference', 59.46, 59.83],
#       ['between', 59.83, 60.15],
#       ['oceanic', 60.15, 60.69],
#       ['plates', 60.69, 61.09],
#       ['and', 61.09, 61.33],
#       ['continental', 61.33, 61.79],
#       ['plates', 61.79, 62.31],
#       ['is', 62.55, 62.73],
#       ['a', 62.73, 62.8],
#       ['paper', 62.8, 63.1],
#       ['priced', 63.1, 63.63],
#       ['finally', 63.63, 64.03],
#       ['complete', 64.03, 64.55],
#       ['%HESITATION', 65.09, 65.21],
#       ['Sienna', 65.21, 65.59],
#       ['crest', 65.59, 66.07],
#       ['and', 66.1, 66.23],
#       ['continental', 66.23, 66.69],
#       ['crust', 66.69, 67.13],
#       ['only', 67.16, 67.38],
#       ['at', 67.38, 67.54],
#       ['a', 67.54, 67.61],
#       ['different', 67.61, 67.95],
#       ['kinds', 67.95, 68.18],
#       ['of', 68.18, 68.28],
#       ['rock', 68.28, 68.72],
#       ['the', 69.03, 69.16],
#       ['continental', 69.16, 69.74],
#       ['crust', 69.74, 70.16],
#       ['contains', 70.16, 70.62],
#       ['a', 70.62, 70.7],
#       ['lot', 70.7, 70.84],
#       ['of', 70.84, 70.94],
#       ['granite', 70.94, 71.52],
#       ['which', 71.77, 71.98],
#       ['is', 71.98, 72.21],
#       ['an', 72.21, 72.36],
#       ['igneous', 72.36, 72.77],
#       ['rock', 72.77, 73.2],
#       ['this', 73.65, 73.88],
#       ['means', 73.88, 74.18],
#       ['that', 74.18, 74.28],
#       ['it', 74.28, 74.34],
#       ['was', 74.34, 74.47],
#       ['made', 74.47, 74.76],
#       ['at', 74.76, 74.86],
#       ['a', 74.86, 74.93],
#       ['rock', 74.93, 75.28],
#       ['that', 75.28, 75.39],
#       ['was', 75.39, 75.54],
#       ['once', 75.54, 75.84],
#       ['Malton', 75.84, 76.45],
#       ['the', 76.72, 76.82],
#       ['oceanic', 76.82, 77.34],
#       ['crust', 77.34, 77.72],
#       ['has', 77.72, 77.84],
#       ['a', 77.84, 77.91],
#       ['lot', 77.91, 78.03],
#       ['of', 78.03, 78.14],
#       ['the', 78.14, 78.24],
#       ['soffit', 78.24, 78.98],
#       ['which', 79.18, 79.4],
#       ['is', 79.4, 79.67],
#       ['another', 79.7, 80.03],
#       ['kind', 80.03, 80.25],
#       ['of', 80.25, 80.33],
#       ['igneous', 80.33, 80.72],
#       ['rock', 80.72, 81.17],
#       ['the', 81.47, 81.61],
#       ['difference', 81.61, 82.06],
#       ['in', 82.06, 82.17],
#       ['the', 82.17, 82.26],
#       ['claims', 82.26, 82.59],
#       ['of', 82.59, 82.7],
#       ['rock', 82.7, 83.02],
#       ['but', 83.02, 83.13],
#       ['the', 83.13, 83.21],
#       ['crusts', 83.21, 83.65],
#       ['are', 83.65, 83.79],
#       ['made', 83.79, 83.97],
#       ['out', 83.97, 84.12],
#       ['it', 84.12, 84.37],
#       ['means', 84.52, 84.83],
#       ['that', 84.83, 85.0],
#       ['the', 85.0, 85.17],
#       ['oceanic', 85.2, 85.72],
#       ['crust', 85.72, 86.26],
#       ['is', 86.26, 86.4],
#       ['denser', 86.4, 86.94],
#       ['than', 86.94, 87.12],
#       ['the', 87.12, 87.2],
#       ['continental', 87.2, 87.76],
#       ['pressed', 87.76, 88.3],
#       ['if', 88.5, 88.64],
#       ['you', 88.64, 88.73],
#       ['took', 88.73, 88.88],
#       ['a', 88.88, 88.92],
#       ['cubic', 88.92, 89.35],
#       ['centimetre', 89.35, 89.93],
#       ['of', 89.93, 90.08],
#       ['a', 90.08, 90.18],
#       ['rock', 90.18, 90.43],
#       ['from', 90.43, 90.57],
#       ['the', 90.57, 90.64],
#       ['customer', 90.64, 91.09],
#       ['crashed', 91.09, 91.7],
#       ['it', 91.73, 91.86],
#       ['would', 91.86, 91.99],
#       ['be', 91.99, 92.22],
#       ['about', 92.22, 92.59],
#       ['two', 92.59, 92.8],
#       ['point', 92.8, 93.12],
#       ['seven', 93.12, 93.38],
#       ['grams', 93.38, 93.96],
#       ['a', 94.2, 94.31],
#       ['cubic', 94.31, 94.67],
#       ['centimetre', 94.67, 95.15],
#       ['from', 95.15, 95.29],
#       ['the', 95.29, 95.39],
#       ['oceanic', 95.39, 95.94],
#       ['crust', 95.94, 96.44],
#       ['and', 96.47, 96.58],
#       ['other', 96.58, 96.76],
#       ['hand', 96.76, 97.17],
#       ['would', 97.2, 97.4],
#       ['weigh', 97.4, 97.69],
#       ['about', 97.69, 98.07],
#       ['three', 98.07, 98.45],
#       ['grams', 98.45, 99.02],
#       ['well', 99.54, 99.69],
#       ['this', 99.69, 99.96],
#       ['difference', 99.96, 100.5],
#       ['in', 100.5, 100.65],
#       ['density', 100.65, 101.19],
#       ['may', 101.19, 101.43],
#       ['not', 101.43, 101.71],
#       ['seem', 101.71, 102.03],
#       ['like', 102.03, 102.26],
#       ['much', 102.26, 102.73],
#       ['completely', 102.82, 103.31],
#       ['changes', 103.31, 103.76],
#       ['how', 103.76, 103.87],
#       ['tectonic', 103.87, 104.38],
#       ['plates', 104.38, 104.78],
#       ['interact', 104.78, 105.58],
#       ['the', 106.06, 106.15],
#       ['high', 106.15, 106.36],
#       ['density', 106.36, 106.8],
#       ['of', 106.8, 106.96],
#       ['authentic', 106.96, 107.37],
#       ['craft', 107.37, 107.9],
#       ['cause', 107.97, 108.24],
#       ['of', 108.24, 108.52],
#       ['scenic', 108.52, 108.87],
#       ['plates', 108.87, 109.36],
#       ['to', 109.4, 109.54],
#       ['think', 109.54, 109.85],
#       ["it's", 109.85, 110.0],
#       ['the', 110.0, 110.17],
#       ['same', 110.17, 110.41],
#       ['spirit', 110.41, 110.85],
#       ['a', 110.85, 110.92],
#       ['bit', 110.92, 111.11],
#       ['more', 111.11, 111.33],
#       ['than', 111.33, 111.45],
#       ['continental', 111.45, 111.96],
#       ['plate', 111.96, 112.17],
#       ['still', 112.17, 112.59],
#       ["we're", 113.25, 113.55],
#       ['also', 113.55, 113.81],
#       ['unique', 113.81, 114.05],
#       ['please', 114.05, 114.35],
#       ['collides', 114.35, 114.76],
#       ['with', 114.76, 114.88],
#       ['another', 114.88, 115.16],
#       ['place', 115.16, 115.43],
#       ['and', 115.43, 115.6],
#       ['a', 115.6, 115.65],
#       ['convergent', 115.65, 116.2],
#       ['boundary', 116.2, 116.74],
#       ['it', 117.08, 117.28],
#       ['always', 117.31, 117.74],
#       ['follows', 117.74, 118.1],
#       ['this', 118.1, 118.31],
#       ['rule', 118.31, 118.68],
#       ['the', 119.18, 119.32],
#       ['denser', 119.32, 119.79],
#       ['plates', 119.79, 120.3],
#       ['always', 120.46, 120.82],
#       ['dies', 120.82, 121.18],
#       ['beneath', 121.18, 121.73],
#       ['the', 121.76, 121.84],
#       ['western', 121.84, 122.22],
#       ['street', 122.22, 122.76],
#       ['with', 123.42, 123.62],
#       ['its', 123.62, 123.76],
#       ['oceanic', 123.76, 124.38],
#       ['plates', 124.38, 124.8],
#       ['and', 124.83, 125.13],
#       ['a', 125.13, 125.19],
#       ['continental', 125.19, 125.77],
#       ['plates', 125.77, 126.12],
#       ['converging', 126.12, 126.91],
#       ['the', 126.99, 127.12],
#       ['denser', 127.12, 127.66],
#       ['oceanic', 127.66, 128.22],
#       ['plates', 128.22, 128.55],
#       ['is', 128.58, 128.72],
#       ['the', 128.72, 128.82],
#       ['one', 128.82, 128.96],
#       ['that', 128.96, 129.07],
#       ['gets', 129.07, 129.28],
#       ['down', 129.28, 129.69],
#       ['and', 130.4, 130.75],
#       ['when', 130.75, 130.89],
#       ["it's", 130.89, 131.07],
#       ['two', 131.07, 131.31],
#       ['of', 131.31, 131.52],
#       ['scenic', 131.52, 131.9],
#       ['places', 131.9, 132.2],
#       ['are', 132.2, 132.27],
#       ['colliding', 132.27, 132.92],
#       ['the', 133.26, 133.44],
#       ['older', 133.44, 133.79],
#       ['denser', 133.79, 134.29],
#       ['of', 134.29, 134.46],
#       ['scenic', 134.46, 134.81],
#       ['please', 134.81, 135.12],
#       ['will', 135.15, 135.3],
#       ['move', 135.3, 135.72],
#       ['under', 135.72, 136.15],
#       ['the', 136.15, 136.3],
#       ['newer', 136.3, 136.68],
#       ['and', 136.68, 136.89],
#       ['less', 136.89, 137.1],
#       ['dense', 137.1, 137.4],
#       ['oceanic', 137.4, 137.91],
#       ['plates', 137.91, 138.32]]}]},
#   {'final': True,
#    'alternatives': [{'transcript': 'and a retirement the denser plates will be recycled into the sea this year the police were the plates collide is called its objections on this bending of the denser plates under the other create a trench the deepest one is the merry honest trench which is located where the Pacific points dives under the merry I please the trenches about eleven kilometres deep ',
#      'confidence': 0.78,
#      'timestamps': [['and', 139.13, 139.27],
#       ['a', 139.27, 139.33],
#       ['retirement', 139.33, 139.99],
#       ['the', 140.12, 140.27],
#       ['denser', 140.27, 140.63],
#       ['plates', 140.63, 140.96],
#       ['will', 140.96, 141.08],
#       ['be', 141.08, 141.19],
#       ['recycled', 141.19, 141.81],
#       ['into', 141.84, 142.03],
#       ['the', 142.03, 142.19],
#       ['sea', 142.19, 142.36],
#       ['this', 142.36, 142.55],
#       ['year', 142.55, 142.93],
#       ['the', 143.29, 143.41],
#       ['police', 143.41, 143.77],
#       ['were', 143.77, 143.84],
#       ['the', 143.84, 143.92],
#       ['plates', 143.92, 144.22],
#       ['collide', 144.22, 144.73],
#       ['is', 144.73, 144.9],
#       ['called', 144.9, 145.23],
#       ['its', 145.23, 145.37],
#       ['objections', 145.37, 145.94],
#       ['on', 145.94, 146.29],
#       ['this', 146.44, 146.76],
#       ['bending', 146.76, 147.27],
#       ['of', 147.27, 147.41],
#       ['the', 147.41, 147.49],
#       ['denser', 147.49, 147.82],
#       ['plates', 147.82, 148.21],
#       ['under', 148.24, 148.46],
#       ['the', 148.46, 148.56],
#       ['other', 148.56, 148.93],
#       ['create', 148.96, 149.41],
#       ['a', 149.44, 149.54],
#       ['trench', 149.54, 150.2],
#       ['the', 150.57, 150.72],
#       ['deepest', 150.72, 151.23],
#       ['one', 151.23, 151.46],
#       ['is', 151.46, 151.65],
#       ['the', 151.65, 151.74],
#       ['merry', 151.74, 152.01],
#       ['honest', 152.01, 152.3],
#       ['trench', 152.3, 152.83],
#       ['which', 153.07, 153.27],
#       ['is', 153.27, 153.39],
#       ['located', 153.39, 153.92],
#       ['where', 153.92, 154.07],
#       ['the', 154.07, 154.16],
#       ['Pacific', 154.16, 154.61],
#       ['points', 154.61, 155.07],
#       ['dives', 155.21, 155.78],
#       ['under', 155.81, 156.11],
#       ['the', 156.11, 156.21],
#       ['merry', 156.21, 156.42],
#       ['I', 156.42, 156.56],
#       ['please', 156.56, 157.04],
#       ['the', 157.44, 157.56],
#       ['trenches', 157.56, 158.12],
#       ['about', 158.12, 158.36],
#       ['eleven', 158.4, 158.86],
#       ['kilometres', 158.86, 159.36],
#       ['deep', 159.36, 159.74]]}]},
#   {'final': True,
#    'alternatives': [{'transcript': "the plate that sinks into the senior Syrian often has some water and fluids trapped inside of it these fluids heat up and bubbles on the surface hopefully with can cause sections of metal rock to melts into magma which then rises to the surface and create volcanoes anybody wondering if the C. four is constantly being destroyed then what gives the earth from shrinking well new C. for its cuts only being created to this happens when two tectonic plates move away from each other at a divergent boundary when two points diverge in the middle of an ocean it creates a kind of underwater mountain range cards are mid ocean ridge as the plates move apart and mid ocean ridges magma moves that cools and forms and new younger less fear you got to get this process like a really slow convey about new ocean C. for is needed the regs and move away from them over millions of years this means that that was the Antichrist for this closest to the ridge is the youngest N. as it moves away from the ridge the crust gets older and older as it ages the crash becomes course and more dents and eventually a defect on edge the city's beer at the trenches ",
#      'confidence': 0.75,
#      'timestamps': [['the', 160.66, 160.78],
#       ['plate', 160.78, 161.08],
#       ['that', 161.08, 161.25],
#       ['sinks', 161.25, 161.53],
#       ['into', 161.53, 161.71],
#       ['the', 161.71, 161.84],
#       ['senior', 161.84, 162.11],
#       ['Syrian', 162.11, 162.63],
#       ['often', 162.82, 163.09],
#       ['has', 163.09, 163.29],
#       ['some', 163.29, 163.47],
#       ['water', 163.47, 163.79],
#       ['and', 163.79, 164.0],
#       ['fluids', 164.0, 164.36],
#       ['trapped', 164.36, 164.61],
#       ['inside', 164.61, 164.87],
#       ['of', 164.87, 164.94],
#       ['it', 164.94, 165.27],
#       ['these', 165.47, 165.74],
#       ['fluids', 165.74, 166.23],
#       ['heat', 166.23, 166.56],
#       ['up', 166.56, 166.87],
#       ['and', 166.9, 167.07],
#       ['bubbles', 167.07, 167.34],
#       ['on', 167.34, 167.42],
#       ['the', 167.42, 167.49],
#       ['surface', 167.49, 168.05],
#       ['hopefully', 168.54, 168.98],
#       ['with', 168.98, 169.2],
#       ['can', 169.2, 169.36],
#       ['cause', 169.36, 169.61],
#       ['sections', 169.61, 170.03],
#       ['of', 170.03, 170.13],
#       ['metal', 170.13, 170.44],
#       ['rock', 170.44, 170.72],
#       ['to', 170.72, 170.88],
#       ['melts', 170.88, 171.22],
#       ['into', 171.22, 171.46],
#       ['magma', 171.46, 172.04],
#       ['which', 172.52, 172.73],
#       ['then', 172.73, 172.9],
#       ['rises', 172.9, 173.31],
#       ['to', 173.31, 173.4],
#       ['the', 173.4, 173.5],
#       ['surface', 173.5, 174.03],
#       ['and', 174.06, 174.21],
#       ['create', 174.21, 174.57],
#       ['volcanoes', 174.57, 175.39],
#       ['anybody', 176.04, 176.53],
#       ['wondering', 176.53, 177.05],
#       ['if', 177.08, 177.23],
#       ['the', 177.23, 177.33],
#       ['C.', 177.33, 177.53],
#       ['four', 177.53, 177.84],
#       ['is', 177.84, 178.03],
#       ['constantly', 178.03, 178.61],
#       ['being', 178.61, 178.84],
#       ['destroyed', 178.84, 179.56],
#       ['then', 179.74, 180.05],
#       ['what', 180.05, 180.34],
#       ['gives', 180.34, 180.58],
#       ['the', 180.58, 180.69],
#       ['earth', 180.69, 180.92],
#       ['from', 180.92, 181.08],
#       ['shrinking', 181.08, 181.7],
#       ['well', 181.99, 182.34],
#       ['new', 182.37, 182.59],
#       ['C.', 182.59, 182.77],
#       ['for', 182.77, 183.08],
#       ['its', 183.08, 183.32],
#       ['cuts', 183.32, 183.66],
#       ['only', 183.66, 183.85],
#       ['being', 183.85, 184.06],
#       ['created', 184.06, 184.53],
#       ['to', 184.53, 184.9],
#       ['this', 185.44, 185.67],
#       ['happens', 185.67, 186.14],
#       ['when', 186.14, 186.27],
#       ['two', 186.27, 186.56],
#       ['tectonic', 186.56, 187.01],
#       ['plates', 187.01, 187.4],
#       ['move', 187.43, 187.62],
#       ['away', 187.62, 187.81],
#       ['from', 187.81, 187.98],
#       ['each', 187.98, 188.1],
#       ['other', 188.1, 188.4],
#       ['at', 188.59, 188.8],
#       ['a', 188.8, 188.87],
#       ['divergent', 188.87, 189.37],
#       ['boundary', 189.37, 190.04],
#       ['when', 190.28, 190.47],
#       ['two', 190.47, 190.66],
#       ['points', 190.66, 191.0],
#       ['diverge', 191.0, 191.66],
#       ['in', 191.69, 191.76],
#       ['the', 191.76, 191.85],
#       ['middle', 191.85, 192.05],
#       ['of', 192.05, 192.13],
#       ['an', 192.13, 192.23],
#       ['ocean', 192.23, 192.76],
#       ['it', 192.95, 193.07],
#       ['creates', 193.07, 193.47],
#       ['a', 193.47, 193.56],
#       ['kind', 193.56, 193.87],
#       ['of', 193.87, 193.98],
#       ['underwater', 193.98, 194.58],
#       ['mountain', 194.58, 194.84],
#       ['range', 194.84, 195.26],
#       ['cards', 195.26, 195.56],
#       ['are', 195.56, 195.69],
#       ['mid', 195.69, 196.1],
#       ['ocean', 196.1, 196.46],
#       ['ridge', 196.46, 197.07],
#       ['as', 197.45, 197.68],
#       ['the', 197.68, 197.77],
#       ['plates', 197.77, 198.18],
#       ['move', 198.18, 198.36],
#       ['apart', 198.36, 198.74],
#       ['and', 198.74, 199.01],
#       ['mid', 199.01, 199.21],
#       ['ocean', 199.21, 199.48],
#       ['ridges', 199.48, 200.06],
#       ['magma', 200.6, 201.07],
#       ['moves', 201.07, 201.4],
#       ['that', 201.4, 201.78],
#       ['cools', 202.08, 202.82],
#       ['and', 203.15, 203.29],
#       ['forms', 203.29, 203.63],
#       ['and', 203.63, 203.91],
#       ['new', 203.91, 204.32],
#       ['younger', 204.37, 204.79],
#       ['less', 204.79, 205.18],
#       ['fear', 205.18, 205.61],
#       ['you', 206.03, 206.13],
#       ['got', 206.13, 206.28],
#       ['to', 206.28, 206.38],
#       ['get', 206.38, 206.5],
#       ['this', 206.5, 206.65],
#       ['process', 206.65, 207.12],
#       ['like', 207.12, 207.35],
#       ['a', 207.38, 207.52],
#       ['really', 207.52, 207.9],
#       ['slow', 207.9, 208.16],
#       ['convey', 208.16, 208.47],
#       ['about', 208.47, 208.99],
#       ['new', 209.41, 209.69],
#       ['ocean', 209.69, 210.05],
#       ['C.', 210.05, 210.22],
#       ['for', 210.22, 210.57],
#       ['is', 210.57, 210.75],
#       ['needed', 210.75, 211.01],
#       ['the', 211.01, 211.1],
#       ['regs', 211.1, 211.62],
#       ['and', 211.65, 211.87],
#       ['move', 211.87, 212.11],
#       ['away', 212.11, 212.3],
#       ['from', 212.3, 212.51],
#       ['them', 212.51, 212.74],
#       ['over', 212.77, 213.02],
#       ['millions', 213.02, 213.49],
#       ['of', 213.49, 213.58],
#       ['years', 213.58, 214.12],
#       ['this', 214.6, 214.8],
#       ['means', 214.8, 215.0],
#       ['that', 215.0, 215.11],
#       ['that', 215.11, 215.25],
#       ['was', 215.25, 215.38],
#       ['the', 215.38, 215.47],
#       ['Antichrist', 215.47, 216.0],
#       ['for', 216.0, 216.11],
#       ['this', 216.11, 216.26],
#       ['closest', 216.26, 216.64],
#       ['to', 216.64, 216.72],
#       ['the', 216.72, 216.82],
#       ['ridge', 216.82, 217.23],
#       ['is', 217.26, 217.36],
#       ['the', 217.36, 217.44],
#       ['youngest', 217.44, 218.06],
#       ['N.', 218.47, 218.62],
#       ['as', 218.62, 218.79],
#       ['it', 218.79, 218.89],
#       ['moves', 218.89, 219.12],
#       ['away', 219.12, 219.3],
#       ['from', 219.3, 219.48],
#       ['the', 219.48, 219.55],
#       ['ridge', 219.55, 219.96],
#       ['the', 219.99, 220.09],
#       ['crust', 220.09, 220.52],
#       ['gets', 220.52, 220.7],
#       ['older', 220.7, 221.12],
#       ['and', 221.12, 221.33],
#       ['older', 221.33, 221.8],
#       ['as', 222.2, 222.41],
#       ['it', 222.41, 222.53],
#       ['ages', 222.53, 222.95],
#       ['the', 222.95, 223.05],
#       ['crash', 223.05, 223.42],
#       ['becomes', 223.42, 223.8],
#       ['course', 223.8, 224.32],
#       ['and', 224.35, 224.5],
#       ['more', 224.5, 224.66],
#       ['dents', 224.66, 225.13],
#       ['and', 225.46, 225.69],
#       ['eventually', 225.69, 226.19],
#       ['a', 226.19, 226.27],
#       ['defect', 226.27, 226.8],
#       ['on', 226.8, 226.95],
#       ['edge', 226.95, 227.09],
#       ['the', 227.09, 227.25],
#       ["city's", 227.25, 227.59],
#       ['beer', 227.59, 227.82],
#       ['at', 227.82, 227.96],
#       ['the', 227.96, 228.03],
#       ['trenches', 228.03, 228.67]]}]},
#   {'final': True,
#    'alternatives': [{'transcript': "the C. four is perhaps the most unexplored product planet so if they do agreement wishin and you go for a walk at the bottom of the sea I hope your time %HESITATION but it's like down there ",
#      'confidence': 0.84,
#      'timestamps': [['the', 229.57, 229.69],
#       ['C.', 229.69, 229.93],
#       ['four', 229.93, 230.41],
#       ['is', 230.44, 230.64],
#       ['perhaps', 230.64, 231.16],
#       ['the', 231.16, 231.27],
#       ['most', 231.27, 231.61],
#       ['unexplored', 231.64, 232.28],
#       ['product', 232.28, 232.67],
#       ['planet', 232.67, 233.2],
#       ['so', 233.38, 233.73],
#       ['if', 233.73, 233.93],
#       ['they', 233.93, 234.06],
#       ['do', 234.06, 234.31],
#       ['agreement', 234.31, 234.77],
#       ['wishin', 234.77, 235.25],
#       ['and', 235.34, 235.51],
#       ['you', 235.51, 235.6],
#       ['go', 235.6, 235.7],
#       ['for', 235.7, 235.87],
#       ['a', 235.87, 235.97],
#       ['walk', 235.97, 236.28],
#       ['at', 236.28, 236.39],
#       ['the', 236.39, 236.47],
#       ['bottom', 236.47, 236.69],
#       ['of', 236.69, 236.76],
#       ['the', 236.76, 236.85],
#       ['sea', 236.85, 237.27],
#       ['I', 237.47, 237.58],
#       ['hope', 237.58, 237.82],
#       ['your', 237.82, 237.98],
#       ['time', 237.98, 238.32],
#       ['%HESITATION', 238.32, 238.6],
#       ['but', 238.6, 238.8],
#       ["it's", 238.8, 238.95],
#       ['like', 238.95, 239.13],
#       ['down', 239.13, 239.31],
#       ['there', 239.31, 239.66]]}]}]}

# %%
actual_list = []
start_list=[]
end_list=[]

# %%
for i in range(0,len(res['results'])):
  actual_list.append(res['results'][i]['alternatives'][0]['transcript'])
  start_list.append(res['results'][i]['alternatives'][0]['timestamps'][0][1])
  end_list.append(res['results'][i]['alternatives'][0]['timestamps'][-1][2])

# %%
actual_list,start_list,end_list
# Out:
# (["imagine that all the recessions disappeared for a day and imagine that you being the excellent explore you are decided to go investigate you travel across the continental shelf down the content of folk and across the business plan you'd think gaping trenches running deep into the ground and mountains total any mountain on the contents and you may wonder what causes such dramatic landscapes to be formed ",
#   'I respect this year which is made by the crest and upper part of the mantle is broken up into large puzzle piece like chunks because tectonic plates these tectonic plates move around slowly over millions of years in the section of mental below the spirit which because the Steelers here ',
#   "there are two types of tectonic plates it was the ethic pleats and continental plates the continental plates as you probably guessed are the ones that make up the confidence that was Yannick pleats are the ones that make up the fee for the main difference between oceanic plates and continental plates is a paper priced finally complete %HESITATION Sienna crest and continental crust only at a different kinds of rock the continental crust contains a lot of granite which is an igneous rock this means that it was made at a rock that was once Malton the oceanic crust has a lot of the soffit which is another kind of igneous rock the difference in the claims of rock but the crusts are made out it means that the oceanic crust is denser than the continental pressed if you took a cubic centimetre of a rock from the customer crashed it would be about two point seven grams a cubic centimetre from the oceanic crust and other hand would weigh about three grams well this difference in density may not seem like much completely changes how tectonic plates interact the high density of authentic craft cause of scenic plates to think it's the same spirit a bit more than continental plate still we're also unique please collides with another place and a convergent boundary it always follows this rule the denser plates always dies beneath the western street with its oceanic plates and a continental plates converging the denser oceanic plates is the one that gets down and when it's two of scenic places are colliding the older denser of scenic please will move under the newer and less dense oceanic plates ",
#   'and a retirement the denser plates will be recycled into the sea this year the police were the plates collide is called its objections on this bending of the denser plates under the other create a trench the deepest one is the merry honest trench which is located where the Pacific points dives under the merry I please the trenches about eleven kilometres deep ',
#   "the plate that sinks into the senior Syrian often has some water and fluids trapped inside of it these fluids heat up and bubbles on the surface hopefully with can cause sections of metal rock to melts into magma which then rises to the surface and create volcanoes anybody wondering if the C. four is constantly being destroyed then what gives the earth from shrinking well new C. for its cuts only being created to this happens when two tectonic plates move away from each other at a divergent boundary when two points diverge in the middle of an ocean it creates a kind of underwater mountain range cards are mid ocean ridge as the plates move apart and mid ocean ridges magma moves that cools and forms and new younger less fear you got to get this process like a really slow convey about new ocean C. for is needed the regs and move away from them over millions of years this means that that was the Antichrist for this closest to the ridge is the youngest N. as it moves away from the ridge the crust gets older and older as it ages the crash becomes course and more dents and eventually a defect on edge the city's beer at the trenches ",
#   "the C. four is perhaps the most unexplored product planet so if they do agreement wishin and you go for a walk at the bottom of the sea I hope your time %HESITATION but it's like down there "],
#  [0.12, 27.72, 45.63, 139.13, 160.66, 229.57],
#  [26.84, 44.51, 138.32, 159.74, 228.67, 239.66])

# %%
import pandas as pd

# Create a list of lists
data = list(zip(actual_list, start_list, end_list))

# Create a DataFrame from the list of lists
df = pd.DataFrame(data, columns=['Text', 'start_time', 'end_time'])

# Print the DataFrame
print(df)
# Out:
#                                                 Text  start_time  end_time
# 0  imagine that all the recessions disappeared fo...        0.12     26.84
# 1  I respect this year which is made by the crest...       27.72     44.51
# 2  there are two types of tectonic plates it was ...       45.63    138.32
# 3  and a retirement the denser plates will be rec...      139.13    159.74
# 4  the plate that sinks into the senior Syrian of...      160.66    228.67
# 5  the C. four is perhaps the most unexplored pro...      229.57    239.66

# %%
df['start_time'][0]
# Out:
# 0.12

# %%
text=res['results'][0]['alternatives'][0]['transcript']
text
# Out:
# "imagine that all the recessions disappeared for a day and imagine that you being the excellent explore you are decided to go investigate you travel across the continental shelf down the content of folk and across the business plan you'd think gaping trenches running deep into the ground and mountains total any mountain on the contents and you may wonder what causes such dramatic landscapes to be formed "

# %% [markdown]
# ## 2. Choose a language and convert text to audio
# Find the ISO code for your target language [here](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html). You can find more details about the languages we currently support for TTS in this [table](https://dl.fbaipublicfiles.com/mms/misc/language_coverage_mms.html).

# %%
# You can pass more than one object in body.
body = [{
    'text': text
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "translations": [
#             {
#                 "text": "ਕਲਪਨਾ ਕਰੋ ਕਿ ਸਾਰੀਆਂ ਮੰਦੀ ਇੱਕ ਦਿਨ ਲਈ ਅਲੋਪ ਹੋ ਗਈਆਂ ਅਤੇ ਕਲਪਨਾ ਕਰੋ ਕਿ ਤੁਸੀਂ ਇੱਕ ਸ਼ਾਨਦਾਰ ਖੋਜਕਰਤਾ ਹੋਣ ਦੇ ਨਾਤੇ, ਤੁਸੀਂ ਜਾਂਚ ਕਰਨ ਦਾ ਫੈਸਲਾ ਕੀਤਾ ਹੈ, ਤੁਸੀਂ ਮਹਾਂਦੀਪ ਦੀ ਸ਼ੈਲਫ ਪਾਰ ਯਾਤਰਾ ਕਰਦੇ ਹੋ, ਲੋਕ ਸਮੱਗਰੀ ਦੀ ਸਮੱਗਰੀ ਨੂੰ ਹੇਠਾਂ ਰੱਖਦੇ ਹੋ, ਅਤੇ ਕਾਰੋਬਾਰੀ ਯੋਜਨਾ ਦੇ ਪਾਰ, ਤੁਸੀਂ ਸੋਚਦੇ ਹੋਵੋਗੇ ਕਿ ਜ਼ਮੀਨ ਵਿੱਚ ਡੂੰਘੀਆਂ ਖੱਡਾਂ ਅਤੇ ਪਹਾੜਾਂ ਦੀ ਸਮੱਗਰੀ 'ਤੇ ਕਿਸੇ ਵੀ ਪਹਾੜ ਨੂੰ ਪੂਰਾ ਕੀਤਾ ਜਾਂਦਾ ਹੈ, ਅਤੇ ਤੁਸੀਂ ਹੈਰਾਨ ਹੋ ਸਕਦੇ ਹੋ ਕਿ ਅਜਿਹੇ ਨਾਟਕੀ ਲੈਂਡਸਕੇਪ ਬਣਨ ਦਾ ਕਾਰਨ ਕੀ ਹੈ, ਮੈਂ ਇਸ ਸਾਲ ਦਾ ਸਤਿਕਾਰ ਕਰਦਾ ਹਾਂ ਜੋ ਬਣਾਇਆ ਗਿਆ ਹੈ ਪਰਤ ਦੇ ਸਿਖਰ ਅਤੇ ਉੱਪਰਲੇ ਹਿੱਸੇ ਨੂੰ ਟੁਕੜਿਆਂ ਵਰਗੇ ਵੱਡੇ ਪਹੇਲੀ ਟੁਕੜੇ ਵਿੱਚ ਵੰਡਿਆ ਜਾਂਦਾ ਹੈ ਕਿਉਂਕਿ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਇਹ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਲੱਖਾਂ ਸਾਲਾਂ ਵਿੱਚ ਆਤਮਾ ਦੇ ਹੇਠਾਂ ਮਾਨਸਿਕ ਭਾਗ ਵਿੱਚ ਹੌਲੀ ਹੌਲੀ ਘੁੰਮਦੀਆਂ ਹਨ, ਕਿਉਂਕਿ ਇੱਥੇ ਸਟੀਲਰਾਂ ਵਿੱਚ ਦੋ ਕਿਸਮਾਂ ਦੀਆਂ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਹੁੰਦੀਆਂ ਹਨ, ਇਹ ਨੈਤਿਕ ਪਲੇਟ ਅਤੇ ਮਹਾਂਦੀਪ ਦੀਆਂ ਪਲੇਟਾਂ ਸਨ, ਜਿਵੇਂ ਕਿ ਤੁਸੀਂ ਸ਼ਾਇਦ ਅੰਦਾਜ਼ਾ ਲਗਾਇਆ ਸੀ, ਉਹ ਉਹ ਹਨ ਜੋ ਵਿਸ਼ਵਾਸ ਪੈਦਾ ਕਰਦੇ ਹਨ ਕਿ ਕੀ ਯਾਨਿਕ ਪਲੇਟਸ ਉਹ ਹਨ ਜੋ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਅਤੇ ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਦੇ ਵਿਚਕਾਰ ਮੁੱਖ ਅੰਤਰ ਲਈ ਫੀਸ ਬਣਾਉਂਦੇ ਹਨ ਇੱਕ ਕਾਗਜ਼ ਦੀ ਕੀਮਤ ਆਖਰਕਾਰ ਪੂਰੀ ਹੁੰਦੀ ਹੈ ٪Tਝਿਜਕ ਸਿਏਨਾ ਕ੍ਰੈਸਟ ਅਤੇ ਮਹਾਂਦੀਪੀ ਪਰਤ ਸਿਰਫ ਇੱਕ ਵੱਖਰੀ ਕਿਸਮ ਦੀ ਚੱਟਾਨ 'ਤੇ ਮਹਾਂਦੀਪ ਦੀ ਪਰਤ ਵਿੱਚ ਬਹੁਤ ਸਾਰਾ ਗ੍ਰੈਨਾਈਟ ਹੁੰਦਾ ਹੈ ਜੋ ਇੱਕ ਅਗਨੀ ਚੱਟਾਨ ਹੈ ਇਸਦਾ ਮਤਲਬ ਇਹ ਹੈ ਕਿ ਇਹ ਇੱਕ ਚੱਟਾਨ 'ਤੇ ਬਣਾਇਆ ਗਿਆ ਸੀ ਜੋ ਕਦੇ ਮਾਲਟਨ ਸੀ, ਸਮੁੰਦਰੀ ਪਰਤ ਵਿੱਚ ਬਹੁਤ ਸਾਰਾ ਸੋਫਿਟ ਹੁੰਦਾ ਹੈ ਜੋ ਕਿ ਇੱਕ ਹੋਰ ਕਿਸਮ ਦੀ ਅਗਨੀ ਚੱਟਾਨ ਹੈ, ਚੱਟਾਨ ਦੇ ਦਾਅਵਿਆਂ ਵਿੱਚ ਅੰਤਰ ਹੈ, ਪਰ ਪਰਤੀਆਂ ਨੂੰ ਬਣਾਇਆ ਗਿਆ ਹੈ, ਇਸਦਾ ਮਤਲਬ ਹੈ ਕਿ ਸਮੁੰਦਰੀ ਪਰਤ ਮਹਾਂਦੀਪ ਦਬਾਏ ਗਏ ਮਹਾਂਦੀਪ ਨਾਲੋਂ ਸੰਘਣੀ ਹੈ, ਜੇ ਤੁਸੀਂ ਗਾਹਕ ਤੋਂ ਇੱਕ ਘਣ ਸੈਂਟੀਮੀਟਰ ਚਟਾਨ ਲੈਂਦੇ ਹੋ, ਤਾਂ ਇਹ ਸਮੁੰਦਰੀ ਪਰਤ ਤੋਂ ਲਗਭਗ ਦੋ ਬਿੰਦੂ ਸੱਤ ਗ੍ਰਾਮ ਪ੍ਰਤੀ ਘਣ ਸੈਂਟੀਮੀਟਰ ਹੋਵੇਗਾ, ਅਤੇ ਦੂਜੇ ਹੱਥ ਦਾ ਭਾਰ ਲਗਭਗ ਤਿੰਨ ਗ੍ਰਾਮ ਹੋਵੇਗਾ; ਘਣਤਾ ਵਿੱਚ ਇਹ ਅੰਤਰ ਨਹੀਂ ਹੋ ਸਕਦਾ ਅਜਿਹਾ ਲੱਗਦਾ ਹੈ ਕਿ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਕਿਵੇਂ ਅੰਤਰਕਿਰਿਆ ਕਰਦੀਆਂ ਹਨ, ਕੁਦਰਤੀ ਪਲੇਟਾਂ ਦੀ ਉੱਚ ਘਣਤਾ ਦਾ ਕਾਰਨ ਇਹ ਸੋਚਣਾ ਕਿ ਇਹ ਮਹਾਂਦੀਪੀ ਪਲੇਟ ਨਾਲੋਂ ਥੋੜ੍ਹਾ ਜਿਹਾ ਜ਼ਿਆਦਾ ਆਤਮਾ ਹੈ, ਫਿਰ ਵੀ ਅਸੀਂ ਵਿਲੱਖਣ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਕਿਸੇ ਹੋਰ ਜਗ੍ਹਾ ਅਤੇ ਇੱਕ ਸਾਂਝੀ ਸੀਮਾ ਨਾਲ ਟਕਰਾਉਂਦੇ ਹਾਂ, ਇਹ ਹਮੇਸ਼ਾਂ ਇਸ ਨਿਯਮ ਦੀ ਪਾਲਣਾ ਕਰਦਾ ਹੈ: ਸੰਘਣੀ ਪਲੇਟਾਂ ਹਮੇਸ਼ਾਂ ਪੱਛਮੀ ਗਲੀ ਦੇ ਹੇਠਾਂ ਆਪਣੀਆਂ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਨਾਲ ਮਰ ਜਾਂਦੀਆਂ ਹਨ, ਅਤੇ ਸੰਘਣੀ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਨੂੰ ਜੋੜਨ ਵਾਲੀਆਂ ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਉਹ ਹਨ ਜੋ ਹੇਠਾਂ ਉਤਰ ਜਾਂਦਾ ਹੈ ਅਤੇ ਜਦੋਂ ਇਹ ਦੋ ਸੁੰਦਰ ਸਥਾਨ ਟਕਰਾ ਰਹੇ ਹੁੰਦੇ ਹਨ, ਤਾਂ ਸੁੰਦਰਤਾ ਦੀ ਪੁਰਾਣੀ ਸੰਘਣੀ, ਕਿਰਪਾ ਕਰਕੇ ਨਵੀਆਂ ਅਤੇ ਘੱਟ ਸੰਘਣੀ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਦੇ ਹੇਠਾਂ ਚਲੇ ਜਾਣਗੇ ਅਤੇ ਰਿਟਾਇਰਮੈਂਟ ਤੋਂ ਬਾਅਦ, ਇਸ ਸਾਲ ਸੰਘਣੀ ਪਲੇਟਾਂ ਨੂੰ ਸਮੁੰਦਰ ਵਿੱਚ ਰੀਸਾਈਕਲ ਕੀਤਾ ਜਾਵੇਗਾ, ਪੁਲਿਸ ਨੂੰ ਪਲੇਟਾਂ ਟਕਰਾਉਣ 'ਤੇ ਇਤਰਾਜ਼ ਕਿਹਾ ਜਾਂਦਾ ਹੈ, ਦੂਜੇ ਦੇ ਹੇਠਾਂ ਸੰਘਣੀ ਪਲੇਟਾਂ ਦੇ ਝੁਕਣ 'ਤੇ ਇਤਰਾਜ਼ ਕੀਤਾ ਜਾਂਦਾ ਹੈ, ਇੱਕ ਖੱਡ ਬਣਾਓ, ਸਭ ਤੋਂ ਡੂੰਘੀ, ਈਮਾਨਦਾਰ ਖੱਡ ਹੈ ਜੋ ਸਥਿਤ ਹੈ ਜਿੱਥੇ ਪ੍ਰਸ਼ਾਂਤ ਖੇਤਰ ਖੁਸ਼ੀ ਦੇ ਹੇਠਾਂ ਡੁੱਬਦਾ ਹੈ, ਮੈਂ ਲਗਭਗ ਗਿਆਰਾਂ ਕਿਲੋਮੀਟਰ ਡੂੰਘੀਆਂ ਖੱਡਾਂ ਨੂੰ ਖੁਸ਼ ਕਰਦਾ ਹਾਂ; ਸੀਨੀਅਰ ਸੀਰੀਆਈ ਵਿੱਚ ਡੁੱਬਣ ਵਾਲੀ ਪਲੇਟ ਵਿੱਚ ਅਕਸਰ ਕੁਝ ਪਾਣੀ ਅਤੇ ਤਰਲ ਪਦਾਰਥ ਫਸ ਜਾਂਦੇ ਹਨ; ਇਹ ਤਰਲ ਪਦਾਰਥ ਗਰਮ ਹੋ ਜਾਂਦੇ ਹਨ ਅਤੇ ਸਤਹ 'ਤੇ ਬੁਲਬੁਲੇ ਹੋਣ ਦੀ ਉਮੀਦ ਹੈ, ਜਿਸ ਨਾਲ ਧਾਤ ਦੀ ਚੱਟਾਨ ਦੇ ਕੁਝ ਹਿੱਸੇ ਮੈਗਮਾ ਵਿੱਚ ਪਿਘਲ ਸਕਦੇ ਹਨ, ਜੋ ਫਿਰ ਸਤਹ 'ਤੇ ਉੱਠਦਾ ਹੈ ਅਤੇ ਜਵਾਲਾਮੁਖੀ ਪੈਦਾ ਕਰਦਾ ਹੈ, ਕੋਈ ਵੀ ਸੋਚਦਾ ਹੈ ਕਿ ਕੀ ਸੀ. ਫੋਰ ਲਗਾਤਾਰ ਤਬਾਹ ਹੋ ਰਿਹਾ ਹੈ ਧਰਤੀ ਨੂੰ ਚੰਗੀ ਤਰ੍ਹਾਂ ਸੁੰਗੜਨ ਤੋਂ ਕਿਹੜੀ ਚੀਜ਼ ਦਿੰਦੀ ਹੈ ਨਵਾਂ C. ਕਿਉਂਕਿ ਇਸ ਦੇ ਕੱਟ ਸਿਰਫ ਉਦੋਂ ਪੈਦਾ ਹੁੰਦੇ ਹਨ ਜਦੋਂ ਦੋ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਇੱਕ ਵੱਖਰੀ ਸੀਮਾ 'ਤੇ ਇੱਕ ਦੂਜੇ ਤੋਂ ਦੂਰ ਜਾਂਦੀਆਂ ਹਨ ਜਦੋਂ ਕਿਸੇ ਸਮੁੰਦਰ ਦੇ ਵਿਚਕਾਰ ਦੋ ਬਿੰਦੂ ਵੱਖ ਹੋ ਜਾਂਦੇ ਹਨ, ਤਾਂ ਇਹ ਇੱਕ ਕਿਸਮ ਦੀ ਪਾਣੀ ਦੇ ਹੇਠਾਂ ਪਹਾੜੀ ਲੜੀ ਦਾ ਨਿਰਮਾਣ ਕਰਦਾ ਹੈ, ਜਿਵੇਂ ਕਿ ਪਲੇਟਾਂ ਵੱਖ ਹੁੰਦੀਆਂ ਹਨ ਅਤੇ ਮੱਧ ਸਮੁੰਦਰ ਦੀਆਂ ਲਕੀਰਾਂ ਮੈਗਮਾ ਚਲਦੀਆਂ ਹਨ ਜੋ ਠੰਡੀਆਂ ਹੁੰਦੀਆਂ ਹਨ ਅਤੇ ਬਣਦੀਆਂ ਹਨ, ਅਤੇ ਨਵੇਂ ਨੌਜਵਾਨ ਤੁਹਾਡੇ ਤੋਂ ਘੱਟ ਡਰਦੇ ਹਨ; ਇਸ ਪ੍ਰਕਿਰਿਆ ਨੂੰ ਨਵੇਂ ਸਮੁੰਦਰ ਬਾਰੇ ਸੱਚਮੁੱਚ ਹੌਲੀ ਜਾਣਕਾਰੀ ਦੀ ਤਰ੍ਹਾਂ ਪ੍ਰਾਪਤ ਕਰਨਾ ਪਿਆ. ਕਿਉਂਕਿ ਲੱਖਾਂ ਸਾਲਾਂ ਤੋਂ ਰੇਗਾਂ ਦੀ ਲੋੜ ਹੈ ਅਤੇ ਉਨ੍ਹਾਂ ਤੋਂ ਦੂਰ ਚਲੇ ਜਾਂਦੇ ਹਨ; ਇਸਦਾ ਮਤਲਬ ਇਹ ਹੈ ਕਿ ਇਹ ਮਸੀਹ ਵਿਰੋਧੀ ਸੀ, ਕਿਉਂਕਿ ਰਿਜ ਦੇ ਸਭ ਤੋਂ ਨੇੜੇ ਸਭ ਤੋਂ ਛੋਟਾ ਐਨ ਹੈ. ਜਿਵੇਂ-ਜਿਵੇਂ ਇਹ ਰਿਜ ਤੋਂ ਦੂਰ ਜਾਂਦਾ ਹੈ, ਪਰਤ ਵਧਦੀ ਜਾਂਦੀ ਹੈ ਅਤੇ ਜਿਵੇਂ-ਜਿਵੇਂ ਇਹ ਉਮਰ ਵਧਦੀ ਜਾਂਦੀ ਹੈ, ਹਾਦਸਾ ਵਧਦਾ ਜਾਂਦਾ ਹੈ, ਹਾਦਸਾ ਵਧਦਾ ਜਾਂਦਾ ਹੈ, ਅਤੇ ਆਖਰਕਾਰ ਕਿਨਾਰੇ 'ਤੇ ਇੱਕ ਨੁਕਸ ਬਣ ਜਾਂਦਾ ਹੈ. ਖੱਡਾਂ 'ਤੇ ਸ਼ਹਿਰ ਦੀ ਬੀਅਰ ਸੀ. ਫੋਰ ਸ਼ਾਇਦ ਸਭ ਤੋਂ ਅਣਜਾਣ ਉਤਪਾਦ ਗ੍ਰਹਿ ਹੈ ਇਸ ਲਈ ਜੇ ਉਹ ਸਹਿਮਤ ਹੁੰਦੇ ਹਨ ਅਤੇ ਤੁਸੀਂ ਸਮੁੰਦਰ ਦੇ ਤਲ 'ਤੇ ਸੈਰ ਕਰਨ ਜਾਂਦੇ ਹੋ ਤਾਂ ਮੈਨੂੰ ਉਮੀਦ ਹੈ ਕਿ ਤੁਹਾਡਾ ਸਮਾਂ ٪ਝਿਜਕ ਜਾਵੇਗਾ ਪਰ ਇਹ ਉੱਥੇ ਵਰਗਾ ਹੈ ",
#                 "to": "pa"
#             }
#         ]
#     }
# ]

# %%
Punjabi_list = []

# %%
df['Text'][0]
# Out:
# "imagine that all the recessions disappeared for a day and imagine that you being the excellent explore you are decided to go investigate you travel across the continental shelf down the content of folk and across the business plan you'd think gaping trenches running deep into the ground and mountains total any mountain on the contents and you may wonder what causes such dramatic landscapes to be formed "

# %%
type(str(df['Text'])),type(res['results'][i]['alternatives'][0]['transcript'])
# Out:
# (str, str)

# %%
for i in range(len(df)):
  #text=res['results'][i]['alternatives'][0]['transcript']
  text=str(df['Text'][i])
  # You can pass more than one object in body.
  body = [{
      'text': text
  }]

  request = requests.post(constructed_url, params=params, headers=headers, json=body)
  response = request.json()

  #print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
  translated_text=response[0]['translations'][0]['text']
  Punjabi_list.append(translated_text)

# %%
Punjabi_list
# Out:
# ["ਕਲਪਨਾ ਕਰੋ ਕਿ ਸਾਰੀਆਂ ਮੰਦੀ ਇੱਕ ਦਿਨ ਲਈ ਅਲੋਪ ਹੋ ਗਈਆਂ ਅਤੇ ਕਲਪਨਾ ਕਰੋ ਕਿ ਤੁਸੀਂ ਇੱਕ ਸ਼ਾਨਦਾਰ ਖੋਜਕਰਤਾ ਹੋਣ ਦੇ ਨਾਤੇ, ਤੁਸੀਂ ਜਾਂਚ ਕਰਨ ਦਾ ਫੈਸਲਾ ਕੀਤਾ ਹੈ, ਤੁਸੀਂ ਮਹਾਂਦੀਪ ਦੀ ਸ਼ੈਲਫ ਪਾਰ ਕਰਦੇ ਹੋ, ਲੋਕ ਸਮੱਗਰੀ ਦੀ ਸਮੱਗਰੀ ਨੂੰ ਹੇਠਾਂ ਰੱਖਦੇ ਹੋ, ਅਤੇ ਕਾਰੋਬਾਰੀ ਯੋਜਨਾ ਦੇ ਪਾਰ ਤੁਸੀਂ ਸੋਚਦੇ ਹੋਵੋਗੇ ਕਿ ਜ਼ਮੀਨ ਵਿੱਚ ਡੂੰਘੀਆਂ ਖੱਡਾਂ ਅਤੇ ਪਹਾੜਾਂ ਦੀ ਸਮੱਗਰੀ 'ਤੇ ਕਿਸੇ ਵੀ ਪਹਾੜ ਨੂੰ ਪੂਰਾ ਕੀਤਾ ਜਾਂਦਾ ਹੈ ਅਤੇ ਤੁਸੀਂ ਹੈਰਾਨ ਹੋ ਸਕਦੇ ਹੋ ਕਿ ਅਜਿਹੇ ਨਾਟਕੀ ਲੈਂਡਸਕੇਪ ਬਣਨ ਦਾ ਕਾਰਨ ਕੀ ਹੈ ",
#  'ਮੈਂ ਇਸ ਸਾਲ ਦਾ ਸਤਿਕਾਰ ਕਰਦਾ ਹਾਂ ਜੋ ਸ਼ਿਖਰ ਦੁਆਰਾ ਬਣਾਇਆ ਗਿਆ ਹੈ ਅਤੇ ਪਰਤ ਦਾ ਉੱਪਰਲਾ ਹਿੱਸਾ ਟੁਕੜਿਆਂ ਵਰਗੇ ਵੱਡੇ ਪਹੇਲੀ ਟੁਕੜੇ ਵਿੱਚ ਟੁੱਟ ਗਿਆ ਹੈ ਕਿਉਂਕਿ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਇਹ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਲੱਖਾਂ ਸਾਲਾਂ ਵਿੱਚ ਆਤਮਾ ਦੇ ਹੇਠਾਂ ਮਾਨਸਿਕ ਭਾਗ ਵਿੱਚ ਹੌਲੀ ਹੌਲੀ ਘੁੰਮਦੀਆਂ ਹਨ ਕਿਉਂਕਿ ਇੱਥੇ ਸਟੀਲਰ ਹਨ ',
#  "ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਦੀਆਂ ਦੋ ਕਿਸਮਾਂ ਹੁੰਦੀਆਂ ਹਨ: ਇਹ ਨੈਤਿਕ ਪਲੇਟਸ ਅਤੇ ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਸਨ; ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਜਿਵੇਂ ਕਿ ਤੁਸੀਂ ਸ਼ਾਇਦ ਅੰਦਾਜ਼ਾ ਲਗਾਇਆ ਸੀ, ਉਹ ਉਹ ਹਨ ਜੋ ਵਿਸ਼ਵਾਸ ਪੈਦਾ ਕਰਦੇ ਹਨ, ਯਾਨਿਕ ਪਲੇਟਸ ਉਹ ਹਨ ਜੋ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਅਤੇ ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਦੇ ਵਿਚਕਾਰ ਮੁੱਖ ਅੰਤਰ ਲਈ ਫੀਸ ਬਣਾਉਂਦੇ ਹਨ, ਇੱਕ ਕਾਗਜ਼ ਹੈ ਜਿਸ ਦੀ ਕੀਮਤ ਆਖਰਕਾਰ ਪੂਰੀ ਹੁੰਦੀ ਹੈ: ٪Tਝਿਜਕ, ਸਿਏਨਾ ਕ੍ਰੈਸਟ ਅਤੇ ਮਹਾਂਦੀਪੀ ਪਰਤ ਸਿਰਫ ਇੱਕ ਵੱਖਰੀ ਕਿਸਮ ਦੀ ਚੱਟਾਨ 'ਤੇ ਹੁੰਦੀ ਹੈ, ਜਿਸ ਵਿੱਚ ਮਹਾਂਦੀਪੀ ਪਰਤ ਹੁੰਦੀ ਹੈ ਬਹੁਤ ਸਾਰਾ ਗ੍ਰੇਨਾਈਟ ਜੋ ਇੱਕ ਅਗਨੀ ਚੱਟਾਨ ਹੈ ਇਸਦਾ ਮਤਲਬ ਇਹ ਹੈ ਕਿ ਇਹ ਇੱਕ ਚੱਟਾਨ 'ਤੇ ਬਣਾਇਆ ਗਿਆ ਸੀ ਜੋ ਕਦੇ ਮਾਲਟਨ ਸੀ, ਸਮੁੰਦਰੀ ਪਰਤ ਵਿੱਚ ਬਹੁਤ ਸਾਰਾ ਸੋਫਿਟ ਹੁੰਦਾ ਹੈ ਜੋ ਕਿ ਇੱਕ ਹੋਰ ਕਿਸਮ ਦੀ ਅਗਨੀ ਚੱਟਾਨ ਹੈ, ਚੱਟਾਨ ਦੇ ਦਾਅਵਿਆਂ ਵਿੱਚ ਅੰਤਰ ਹੈ ਪਰ ਪਰਤੀਆਂ ਬਣਾਈਆਂ ਜਾਂਦੀਆਂ ਹਨ; ਇਸਦਾ ਮਤਲਬ ਹੈ ਕਿ ਸਮੁੰਦਰੀ ਪਰਤ ਮਹਾਂਦੀਪੀ ਦਬਾਅ ਨਾਲੋਂ ਸੰਘਣੀ ਹੈ, ਜੇ ਤੁਸੀਂ ਗਾਹਕ ਤੋਂ ਇੱਕ ਘਣ ਸੈਂਟੀਮੀਟਰ ਚੱਟਾਨ ਲੈਂਦੇ ਹੋ ਇਹ ਸਮੁੰਦਰੀ ਪਰਤ ਤੋਂ ਲਗਭਗ ਦੋ ਬਿੰਦੂ ਸੱਤ ਗ੍ਰਾਮ ਪ੍ਰਤੀ ਕਿਊਬਿਕ ਸੈਂਟੀਮੀਟਰ ਹੋਵੇਗਾ ਅਤੇ ਦੂਜੇ ਹੱਥ ਦਾ ਭਾਰ ਲਗਭਗ ਤਿੰਨ ਗ੍ਰਾਮ ਹੋਵੇਗਾ, ਘਣਤਾ ਵਿੱਚ ਇਹ ਅੰਤਰ ਪੂਰੀ ਤਰ੍ਹਾਂ ਬਦਲਿਆ ਨਹੀਂ ਜਾਪਦਾ, ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਕਿਵੇਂ ਪ੍ਰਮਾਣਿਕ ਕ੍ਰਾਫਟ ਦੀ ਉੱਚ ਘਣਤਾ ਨਾਲ ਗੱਲਬਾਤ ਕਰਦੀਆਂ ਹਨ, ਸੁੰਦਰ ਪਲੇਟਾਂ ਦੇ ਕਾਰਨ ਇਹ ਸੋਚਣਾ ਕਿ ਇਹ ਮਹਾਂਦੀਪੀ ਪਲੇਟ ਨਾਲੋਂ ਥੋੜ੍ਹਾ ਜਿਹਾ ਜ਼ਿਆਦਾ ਆਤਮਾ ਹੈ, ਫਿਰ ਵੀ ਅਸੀਂ ਵਿਲੱਖਣ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਕਿਸੇ ਹੋਰ ਜਗ੍ਹਾ ਅਤੇ ਇੱਕ ਕਨਵਰਜੈਂਟ ਸੀਮਾ ਨਾਲ ਟਕਰਾਓ ਇਹ ਹਮੇਸ਼ਾਂ ਇਸ ਨਿਯਮ ਦੀ ਪਾਲਣਾ ਕਰਦਾ ਹੈ ਸੰਘਣੀ ਪਲੇਟਾਂ ਹਮੇਸ਼ਾਂ ਪੱਛਮੀ ਗਲੀ ਦੇ ਹੇਠਾਂ ਆਪਣੀਆਂ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਨਾਲ ਮਰ ਜਾਂਦੀਆਂ ਹਨ ਅਤੇ ਸੰਘਣੀ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਨੂੰ ਜੋੜਨ ਵਾਲੀ ਮਹਾਂਦੀਪੀ ਪਲੇਟਾਂ ਉਹ ਹੁੰਦੀਆਂ ਹਨ ਜੋ ਹੇਠਾਂ ਆਉਂਦੀਆਂ ਹਨ ਅਤੇ ਜਦੋਂ ਇਹ ਦੋ ਸੁੰਦਰ ਸਥਾਨ ਾਂ ਨਾਲ ਟਕਰਾ ਰਹੀਆਂ ਹੁੰਦੀਆਂ ਹਨ ਤਾਂ ਸੁੰਦਰਤਾ ਦੀਆਂ ਪੁਰਾਣੀਆਂ ਸੰਘਣੀ ਪਲੇਟਾਂ ਦੇ ਹੇਠਾਂ ਚਲੇ ਜਾਂਦੇ ਹਨ ਕਿਰਪਾ ਕਰਕੇ ਨਵੀਆਂ ਅਤੇ ਘੱਟ ਸੰਘਣੀ ਸਮੁੰਦਰੀ ਪਲੇਟਾਂ ਦੇ ਹੇਠਾਂ ਚਲੇ ਜਾਣਗੇ ",
#  "ਅਤੇ ਰਿਟਾਇਰਮੈਂਟ ਤੋਂ ਬਾਅਦ, ਇਸ ਸਾਲ ਸੰਘਣੀ ਪਲੇਟਾਂ ਨੂੰ ਸਮੁੰਦਰ ਵਿੱਚ ਰੀਸਾਈਕਲ ਕੀਤਾ ਜਾਵੇਗਾ, ਪੁਲਿਸ ਜੇ ਪਲੇਟਾਂ ਟਕਰਾਉਂਦੀਆਂ ਹਨ, ਤਾਂ ਦੂਜੇ ਦੇ ਹੇਠਾਂ ਸੰਘਣੀ ਪਲੇਟਾਂ ਦੇ ਝੁਕਣ 'ਤੇ ਉਸ ਦੇ ਇਤਰਾਜ਼ ਾਂ ਨੂੰ ਕਿਹਾ ਜਾਂਦਾ ਹੈ, ਇੱਕ ਖੱਡ ਬਣਾਓ, ਸਭ ਤੋਂ ਡੂੰਘੀ, ਈਮਾਨਦਾਰ ਖੱਡ ਹੈ ਜੋ ਸਥਿਤ ਹੈ ਜਿੱਥੇ ਪ੍ਰਸ਼ਾਂਤ ਬਿੰਦੂ ਖੁਸ਼ੀ ਦੇ ਹੇਠਾਂ ਡੁੱਬਦੇ ਹਨ, ਮੈਂ ਲਗਭਗ ਗਿਆਰਾਂ ਕਿਲੋਮੀਟਰ ਡੂੰਘੀਆਂ ਖੱਡਾਂ ਨੂੰ ਖੁਸ਼ ਕਰਦਾ ਹਾਂ ",
#  "ਬਜ਼ੁਰਗ ਸੀਰੀਆਈ ਵਿੱਚ ਡੁੱਬਣ ਵਾਲੀ ਪਲੇਟ ਵਿੱਚ ਅਕਸਰ ਕੁਝ ਪਾਣੀ ਅਤੇ ਤਰਲ ਪਦਾਰਥ ਫਸ ਜਾਂਦੇ ਹਨ, ਇਹ ਤਰਲ ਪਦਾਰਥ ਗਰਮ ਹੋ ਜਾਂਦੇ ਹਨ ਅਤੇ ਸਤਹ 'ਤੇ ਬੁਲਬੁਲੇ ਹੋਣ ਦੀ ਉਮੀਦ ਹੈ, ਜਿਸ ਨਾਲ ਧਾਤ ਦੀ ਚੱਟਾਨ ਦੇ ਕੁਝ ਹਿੱਸੇ ਮੈਗਮਾ ਵਿੱਚ ਪਿਘਲ ਸਕਦੇ ਹਨ, ਜੋ ਫਿਰ ਸਤਹ 'ਤੇ ਉੱਠਦਾ ਹੈ ਅਤੇ ਜਵਾਲਾਮੁਖੀ ਪੈਦਾ ਕਰਦਾ ਹੈ, ਕੋਈ ਵੀ ਹੈਰਾਨ ਹੈ ਕਿ ਜੇ ਸੀ. ਚਾਰ ਲਗਾਤਾਰ ਤਬਾਹ ਹੋ ਰਿਹਾ ਹੈ, ਤਾਂ ਧਰਤੀ ਨੂੰ ਚੰਗੀ ਤਰ੍ਹਾਂ ਸੁੰਗੜਨ ਤੋਂ ਕਿਹੜੀ ਚੀਜ਼ ਦਿੰਦੀ ਹੈ? ਇਹ ਉਦੋਂ ਵਾਪਰਦਾ ਹੈ ਜਦੋਂ ਦੋ ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਇੱਕ ਵੱਖਰੀ ਸੀਮਾ 'ਤੇ ਇੱਕ ਦੂਜੇ ਤੋਂ ਦੂਰ ਜਾਂਦੀਆਂ ਹਨ, ਜਦੋਂ ਕਿਸੇ ਸਮੁੰਦਰ ਦੇ ਵਿਚਕਾਰ ਦੋ ਬਿੰਦੂ ਵੱਖਰੇ ਹੁੰਦੇ ਹਨ, ਤਾਂ ਇਹ ਇੱਕ ਕਿਸਮ ਦੀ ਪਾਣੀ ਦੇ ਹੇਠਾਂ ਪਹਾੜੀ ਲੜੀ ਦੇ ਕਾਰਡ ਪੈਦਾ ਕਰਦੇ ਹਨ: ਮੱਧ ਮਹਾਂਸਾਗਰ ਰਿਜ ਜਿਵੇਂ ਕਿ ਪਲੇਟਾਂ ਵੱਖ ਹੁੰਦੀਆਂ ਹਨ ਅਤੇ ਮੱਧ ਮਹਾਂਸਾਗਰ ਦੀਆਂ ਲਕੀਰਾਂ ਮੈਗਮਾ ਚਲਦੀਆਂ ਹਨ ਜੋ ਠੰਡੀਆਂ ਹੁੰਦੀਆਂ ਹਨ ਅਤੇ ਬਣਦੀਆਂ ਹਨ, ਅਤੇ ਨਵੀਂ ਛੋਟੀ ਉਮਰ ਵਿੱਚ, ਤੁਹਾਨੂੰ ਇਸ ਪ੍ਰਕਿਰਿਆ ਨੂੰ ਨਵੇਂ ਮਹਾਂਸਾਗਰ C ਬਾਰੇ ਸੱਚਮੁੱਚ ਹੌਲੀ ਹਵਾ ਵਾਂਗ ਪ੍ਰਾਪਤ ਕਰਨ ਦਾ ਮੌਕਾ ਮਿਲਦਾ ਹੈ। ਲੱਖਾਂ ਸਾਲਾਂ ਤੋਂ ਰੇਗਾਂ ਦੀ ਲੋੜ ਸੀ ਅਤੇ ਉਨ੍ਹਾਂ ਤੋਂ ਦੂਰ ਚਲੇ ਗਏ, ਇਸਦਾ ਮਤਲਬ ਇਹ ਹੈ ਕਿ ਇਹ ਮਸੀਹ ਵਿਰੋਧੀ ਸੀ, ਕਿਉਂਕਿ ਰਿਜ ਦੇ ਸਭ ਤੋਂ ਨੇੜੇ ਸਭ ਤੋਂ ਛੋਟਾ ਐਨ ਹੈ. ਜਿਵੇਂ-ਜਿਵੇਂ ਇਹ ਪਹਾੜੀ ਤੋਂ ਦੂਰ ਜਾਂਦਾ ਹੈ, ਪਰਤ ਵਧਦੀ ਜਾਂਦੀ ਹੈ ਅਤੇ ਉਮਰ ਵਧਣ ਦੇ ਨਾਲ-ਨਾਲ ਇਹ ਹਾਦਸਾ ਹੋਰ ਵੀ ਵੱਡਾ ਹੁੰਦਾ ਜਾਂਦਾ ਹੈ, ਅਤੇ ਆਖਰਕਾਰ ਖੱਡਾਂ ਵਿੱਚ ਸ਼ਹਿਰ ਦੀ ਬੀਅਰ ਦੇ ਕਿਨਾਰੇ ਇੱਕ ਨੁਕਸ ਬਣ ਜਾਂਦਾ ਹੈ ",
#  "ਸੀ. ਫੋਰ ਸ਼ਾਇਦ ਸਭ ਤੋਂ ਅਣਜਾਣ ਉਤਪਾਦ ਗ੍ਰਹਿ ਹੈ ਇਸ ਲਈ ਜੇ ਉਹ ਸਹਿਮਤ ਹੁੰਦੇ ਹਨ ਅਤੇ ਤੁਸੀਂ ਸਮੁੰਦਰ ਦੇ ਤਲ 'ਤੇ ਸੈਰ ਕਰਨ ਜਾਂਦੇ ਹੋ ਤਾਂ ਮੈਨੂੰ ਉਮੀਦ ਹੈ ਕਿ ਤੁਹਾਡਾ ਸਮਾਂ ٪ਝਿਜਕ ਜਾਵੇਗਾ ਪਰ ਇਹ ਹੇਠਾਂ ਵਰਗਾ ਹੈ "]

# %%
df["translated"]=Punjabi_list

# %%
df['duration']=df['end_time']-df['start_time']
df
# Out:
#                                                 Text  start_time  end_time  \
# 0  imagine that all the recessions disappeared fo...        0.12     26.84
# 1  I respect this year which is made by the crest...       27.72     44.51
# 2  there are two types of tectonic plates it was ...       45.63    138.32
# 3  and a retirement the denser plates will be rec...      139.13    159.74
# 4  the plate that sinks into the senior Syrian of...      160.66    228.67
# 5  the C. four is perhaps the most unexplored pro...      229.57    239.66
#
#                                           translated  duration
# 0  ਕਲਪਨਾ ਕਰੋ ਕਿ ਸਾਰੀਆਂ ਮੰਦੀ ਇੱਕ ਦਿਨ ਲਈ ਅਲੋਪ ਹੋ ਗਈ...     26.72
# 1  ਮੈਂ ਇਸ ਸਾਲ ਦਾ ਸਤਿਕਾਰ ਕਰਦਾ ਹਾਂ ਜੋ ਸ਼ਿਖਰ ਦੁਆਰਾ ਬ...     16.79
# 2  ਟੈਕਟੋਨਿਕ ਪਲੇਟਾਂ ਦੀਆਂ ਦੋ ਕਿਸਮਾਂ ਹੁੰਦੀਆਂ ਹਨ: ਇਹ ...     92.69
# 3  ਅਤੇ ਰਿਟਾਇਰਮੈਂਟ ਤੋਂ ਬਾਅਦ, ਇਸ ਸਾਲ ਸੰਘਣੀ ਪਲੇਟਾਂ ਨ...     20.61
# 4  ਬਜ਼ੁਰਗ ਸੀਰੀਆਈ ਵਿੱਚ ਡੁੱਬਣ ਵਾਲੀ ਪਲੇਟ ਵਿੱਚ ਅਕਸਰ ਕ...     68.01
# 5  ਸੀ. ਫੋਰ ਸ਼ਾਇਦ ਸਭ ਤੋਂ ਅਣਜਾਣ ਉਤਪਾਦ ਗ੍ਰਹਿ ਹੈ ਇਸ ਲ...     10.09

# %%
df['duration']=df['duration'].astype(float)
type(df['duration'])
# Out:
# pandas.core.series.Series

# %%
print(df['duration'].dtype)
# Out:
# float64

# %%
# %pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment

# %%
generated_audios = []

for i in range(len(Punjabi_list)):
    txt = str(df['translated'][i])
    txt = preprocess_text(txt, text_mapper, hps, lang=LANG)
    stn_tst = text_mapper.get_text(txt, hps)

    with torch.no_grad():
        x_tst = stn_tst.unsqueeze(0).to(device)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).to(device)
        hyp = net_g.infer(
            x_tst, x_tst_lengths, noise_scale=.667,
            noise_scale_w=0.8, length_scale=1.0
        )[0][0,0].cpu().float().numpy()

    print(f"Generated audio")

    # Append the generated audio to the list
    generated_audios.append(hyp)

# Now, 'generated_audios' contains the generated audio arrays for each iteration
# You can access them using generated_audios[index]

# For example, to access the first generated audio:
first_generated_audio = generated_audios[0]
# Out:
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio

# %%
from pydub import AudioSegment
import numpy as np

# Initialize an empty list to store generated audios
generated_audios = []

# Manually set sample_width and num_mels based on your audio data
sample_width = 2  # Adjust this based on your audio data (commonly 1 or 2)
num_mels = 1  # Adjust this based on your audio data

for i in range(len(Punjabi_list)):
    txt = str(df['translated'][i])
    txt = preprocess_text(txt, text_mapper, hps, lang=LANG)
    stn_tst = text_mapper.get_text(txt, hps)

    with torch.no_grad():
        x_tst = stn_tst.unsqueeze(0).to(device)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).to(device)
        hyp = net_g.infer(
            x_tst, x_tst_lengths, noise_scale=.667,
            noise_scale_w=0.8, length_scale=1.0
        )[0][0,0].cpu().float().numpy()

    print(f"Generated audio")

    # Convert numpy array to AudioSegment
    hyp_audio_segment = AudioSegment(
        hyp.astype(np.int16).tobytes(),
        frame_rate=hps.data.sampling_rate,
        sample_width=sample_width,
        channels=num_mels
    )

    # Append the generated audio as an AudioSegment to the list
    generated_audios.append(hyp_audio_segment)
# Out:
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio

# %%
generated_audios[0]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
generated_audio_list = []
for i in range(len(Punjabi_list)):
  #Text = "ਮੇਰਾ ਨਾਮ ਅਲੀ ਹੈ। ਮੈਂ ਨਦੀ ਦੇ ਕਿਨਾਰੇ ਪੜ੍ਹਦਾ ਹਾਂ। ਮੈਨੂੰ ਸਾਰੀ ਰਾਤ ਪਾਰਟੀ ਕਰਨਾ ਪਸੰਦ ਹੈ।" #@param {type:"string"}
  # Text=res
  txt = str(df['translated'][i])
  txt = preprocess_text(txt, text_mapper, hps, lang=LANG)
  stn_tst = text_mapper.get_text(txt, hps)
  with torch.no_grad():
      x_tst = stn_tst.unsqueeze(0).to(device)
      x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).to(device)
      hyp = net_g.infer(
          x_tst, x_tst_lengths, noise_scale=.667,
          noise_scale_w=0.8, length_scale=1.0
      )[0][0,0].cpu().float().numpy()

  hyp_np = hyp.astype(np.int16)

    # Convert numpy array to AudioSegment
  audio_segment = AudioSegment(
        hyp_np.tobytes(),
        frame_rate=hps.data.sampling_rate,
        sample_width=hyp.dtype.itemsize,
        channels=1
    )

    # Append AudioSegment to the list
  generated_audio_list.append(audio_segment)
  # Save the generated audio as a WAV file
  #path="/content/audio.wav"
  #output_wav_path = "/content/"+str(i)+"generated_audio.wav"
  #os.makedirs(output_wav_path, exist_ok=True)
  #sf.write(output_wav_path, hyp, hps.data.sampling_rate, format='WAV', endian='LITTLE', subtype='PCM_16')
  #Audio(hyp, rate=hps.data.sampling_rate)
# Out:
# pan
# pan
# pan
# pan
# pan
# pan

# %%
from pydub import AudioSegment
import numpy as np

generated_audios = []

for i in range(len(Punjabi_list)):
    txt = str(df['translated'][i])
    txt = preprocess_text(txt, text_mapper, hps, lang=LANG)
    stn_tst = text_mapper.get_text(txt, hps)

    with torch.no_grad():
        x_tst = stn_tst.unsqueeze(0).to(device)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).to(device)
        hyp = net_g.infer(
            x_tst, x_tst_lengths, noise_scale=.667,
            noise_scale_w=0.8, length_scale=1.0
        )[0][0,0].cpu().float().numpy()

    print(f"Generated audio")

    # Convert the generated audio array to 16-bit PCM format
    hyp_int16 = (hyp * 32767).astype(np.int16)

    # Create an AudioSegment from the NumPy array
    hyp1 = AudioSegment(
        hyp_int16.tobytes(),
        frame_rate=hps.data.sampling_rate,
        sample_width=hyp_int16.dtype.itemsize,
        channels=1
    )

    # Save the generated audio as a WAV file
    #output_wav_path = f"/content/{i}_generated_audio.wav"
    #hyp1.export(output_wav_path, format="wav")

    # Append the file path to the list
    generated_audios.append(hyp1)

# Now, 'generated_audios' contains the paths to the generated WAV files for each iteration
# You can access them using generated_audios[index]

# For example, to access the first generated audio path:
first_generated_audio_path = generated_audios[0]
# Out:
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio
# pan
# Generated audio

# %%
first_generated_audio_path
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# %pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment

# %%
stretched=[]

# %%
original=audio_segment.from_wav("/content/audio.wav")

# %%
len(original)
# Out:
# 239885

# %%
from pydub import AudioSegment
import numpy as np

# Function to speed up audio
def speed_up_audio(audio, speed_factor):
    # Speed up the audio
    sped_up_audio = audio.speedup(playback_speed=speed_factor)
    return sped_up_audio

# Function to create an empty audio segment
def create_empty_segment(duration):
    return AudioSegment.silent(duration=duration * 1000)  # Duration in milliseconds

# Function to add an audio segment to the project at a specific time
def add_audio_at_time(project, audio_segment, start_time, end_time):
    project = project[:start_time * 1000] + audio_segment + project[end_time * 1000:]
    return project

# Specify the duration of the empty audio (in seconds)
empty_duration = len(original) / 1000

# Create an empty audio segment
project = create_empty_segment(empty_duration)

# List to store the stretched audio segments
stretched_segments = []

# Assuming stretched is a list of AudioSegment objects
for i in range(len(df)):
    # Example usage: Replace this line with your code to get the stretched audio segment
    stretched_audio = generated_audios[i]

    # Speed up the audio segment based on the duration
    speed_factor = (len(stretched_audio)/1000) / df['duration'].iloc[i]
    stretched_audio = speed_up_audio(stretched_audio, speed_factor)

    # Append the stretched audio segment to the list
    stretched_segments.append(stretched_audio)

# Add each stretched audio segment to the project at the specified start and end times
for i, stretched_audio in enumerate(stretched_segments):
    project = add_audio_at_time(project, stretched_audio, df['start_time'].iloc[i], df['end_time'].iloc[i])

# Export the final audio project
output_file = "/content/output_project.wav"
project.export(output_file, format="wav")

print(f"Dubbing project exported to {output_file}")
# Out:
# Dubbing project exported to /content/output_project.wav

# %%
project
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
type(project)
# Out:
# pydub.audio_segment.AudioSegment

# %%
# %pip install moviepy pydub imageio[ffmpeg]
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.23.5)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]) (9.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from imageio[ffmpeg]) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2023.11.17)

# %%
from moviepy.editor import VideoFileClip, AudioFileClip
from pydub import AudioSegment
import numpy as np
import io
import soundfile as sf

# Assume 'video_path' is the path to your MP4 video
video_path = 'path/to/your/video.mp4'

# Assume 'audio_segment' is your AudioSegment
# For example, you can access it from your generated_audios list
audio_segment = generated_audios[0]

# Create an in-memory AudioFileClip from the AudioSegment
audio_clip = AudioFileClip(io.BytesIO(audio_segment.raw_data), fps=audio_segment.frame_rate)

# Load the video clip
video_clip = VideoFileClip(video_path)

# Set the audio of the video clip to the loaded audio
video_clip = video_clip.set_audio(audio_clip)

# Write the new video with the added audio to a file or display it
video_clip.write_videofile('output_video.mp4', codec='libx264', audio_codec='aac')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-89b9299b5f0c> in <cell line: 15>()
#      13
#      14 # Create an in-memory AudioFileClip from the AudioSegment
# ---> 15 audio_clip = AudioFileClip(io.BytesIO(audio_segment.raw_data), fps=audio_segment.frame_rate)
#      16
#      17 # Load the video clip
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/AudioFileClip.py in __init__(self, filename, buffersize, nbytes, fps)
#      68
#      69         self.filename = filename
# ---> 70         self.reader = FFMPEG_AudioReader(filename, fps=fps, nbytes=nbytes,
#      71                                          buffersize=buffersize)
#      72         self.fps = fps
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/readers.py in __init__(self, filename, buffersize, print_infos, fps, nbytes, nchannels)
#      49         self.acodec = 'pcm_s%dle'%(8*nbytes)
#      50         self.nchannels = nchannels
# ---> 51         infos = ffmpeg_parse_infos(filename)
#      52         self.duration = infos['duration']
#      53         if 'video_duration' in infos:
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     242
#     243     # open the file in a pipe, provoke an error, read output
# --> 244     is_GIF = filename.endswith('.gif')
#     245     cmd = [get_setting("FFMPEG_BINARY"), "-i", filename]
#     246     if is_GIF:
#
# AttributeError: '_io.BytesIO' object has no attribute 'endswith'

# %%
mp3_data = audio_segment.export(format="mp3").read()

# %%
# Open the video and audio
video_clip = VideoFileClip("/content/a.mp4")
audio_clip = AudioFileClip(mp3_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-75219c3e50da> in <cell line: 3>()
#       1 # Open the video and audio
#       2 video_clip = VideoFileClip("/content/a.mp4")
# ----> 3 audio_clip = AudioFileClip(mp3_data)
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/AudioFileClip.py in __init__(self, filename, buffersize, nbytes, fps)
#      68
#      69         self.filename = filename
# ---> 70         self.reader = FFMPEG_AudioReader(filename, fps=fps, nbytes=nbytes,
#      71                                          buffersize=buffersize)
#      72         self.fps = fps
#
# /usr/local/lib/python3.10/dist-packages/moviepy/audio/io/readers.py in __init__(self, filename, buffersize, print_infos, fps, nbytes, nchannels)
#      49         self.acodec = 'pcm_s%dle'%(8*nbytes)
#      50         self.nchannels = nchannels
# ---> 51         infos = ffmpeg_parse_infos(filename)
#      52         self.duration = infos['duration']
#      53         if 'video_duration' in infos:
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     242
#     243     # open the file in a pipe, provoke an error, read output
# --> 244     is_GIF = filename.endswith('.gif')
#     245     cmd = [get_setting("FFMPEG_BINARY"), "-i", filename]
#     246     if is_GIF:
#
# TypeError: endswith first arg must be bytes or a tuple of bytes, not str

# %%
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
import io

# Assume 'audio_segment' is your AudioSegment object
# For example, you can access it from your generated_audios list
audio_segment = project

# Convert AudioSegment to MP3 format
mp3_data = audio_segment.export(format="mp3").read()

# Save the MP3 data to a temporary file
temp_mp3_path = "/content/temp_audio.mp3"
with open(temp_mp3_path, "wb") as f:
    f.write(mp3_data)

# Open the video and audio
video_clip = VideoFileClip("/content/a.mp4")
audio_clip = AudioFileClip(temp_mp3_path)

# Set the audio of the video clip to the loaded audio
video_clip = video_clip.set_audio(audio_clip)

# Write the new video with the added audio to a file or display it
video_clip.write_videofile('/content/output_video.mp4', codec='libx264', audio_codec='aac')

# Cleanup: Delete the temporary MP3 file
os.remove(temp_mp3_path)
# Out:
# Moviepy - Building video /content/output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video /content/output_video.mp4
# t: 100%|█████████▉| 7170/7190 [00:36<00:00, 228.13it/s, now=None][WARNING] /usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/a.mp4, 691200 bytes wanted but 0 bytes read,at frame 7189/7190, at time 239.87/239.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready /content/output_video.mp4

# %%
# Concatenate the video clip with the audio clip
final_clip = video_clip.set_audio(audio_clip)

# %%
# Write the merged video file to a new file
final_clip.write_videofile("/content/drive/MyDrive/Colab Notebooks/Imagine Cup 2024/Videos/"+title+".mp4")
# Out:
# Moviepy - Building video /content/drive/MyDrive/Colab Notebooks/Imagine Cup 2024/Videos/Plate tectonics.mp4.
# MoviePy - Writing audio in Plate tectonicsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/Colab Notebooks/Imagine Cup 2024/Videos/Plate tectonics.mp4
# t: 100%|█████████▉| 7175/7190 [00:38<00:00, 213.70it/s, now=None][WARNING] /usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/a.mp4, 691200 bytes wanted but 0 bytes read,at frame 7189/7190, at time 239.87/239.89 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/Colab Notebooks/Imagine Cup 2024/Videos/Plate tectonics.mp4

# %%
os.remove("/content/a.mp4")
os.remove("/content/audio.wav")
os.remove("/content/generated_audio.wav")
